# %% [markdown]
# # WeatherAPI (Weather)
#
# Answer the following questions using [WeatherAPI](http://www.weatherapi.com/). I've added three cells for most questions but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# Be sure to take advantage of both the documentation and the API Explorer!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*
# - *Tip: Remember you only need to import requests once!*

# %%
import requests
import json

response = requests.get("http://api.weatherapi.com/v1/current.json?key=a5a33e5547704451b06180649211906&q=Pittsburgh")
data = response.json()
print(data)
# Out:
# {'location': {'name': 'Pittsburgh', 'region': 'Pennsylvania', 'country': 'United States of America', 'lat': 40.44, 'lon': -80.0, 'tz_id': 'America/New_York', 'localtime_epoch': 1624227677, 'localtime': '2021-06-20 18:21'}, 'current': {'last_updated_epoch': 1624227300, 'last_updated': '2021-06-20 18:15', 'temp_c': 30.0, 'temp_f': 86.0, 'is_day': 1, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'wind_mph': 11.9, 'wind_kph': 19.1, 'wind_degree': 210, 'wind_dir': 'SSW', 'pressure_mb': 1008.0, 'pressure_in': 30.2, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 55, 'cloud': 25, 'feelslike_c': 32.4, 'feelslike_f': 90.4, 'vis_km': 16.0, 'vis_miles': 9.0, 'uv': 6.0, 'gust_mph': 9.6, 'gust_kph': 15.5}}

# %% [markdown]
# ## 1) Make a request to the Weather API for where you were born (or lived, or want to visit!).
#
# - *Tip: This sure seems familiar.*

# %%
data.keys()
# Out:
# dict_keys(['location', 'current'])

# %%
data['location']['name']
# Out:
# 'Pittsburgh'

# %%
print(f"This is the weather API for" , (data['location']['name']) , ", where I was born and went to undergrad.")
# Out:
# This is the weather API for Pittsburgh , where I was born and went to undergrad.

# %% [markdown]
# ## 2) What's the current wind speed, and how much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference. Same as we did last time!*

# %%
data['current']
# Out:
# {'last_updated_epoch': 1624227300,
#  'last_updated': '2021-06-20 18:15',
#  'temp_c': 30.0,
#  'temp_f': 86.0,
#  'is_day': 1,
#  'condition': {'text': 'Partly cloudy',
#   'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#   'code': 1003},
#  'wind_mph': 11.9,
#  'wind_kph': 19.1,
#  'wind_degree': 210,
#  'wind_dir': 'SSW',
#  'pressure_mb': 1008.0,
#  'pressure_in': 30.2,
#  'precip_mm': 0.0,
#  'precip_in': 0.0,
#  'humidity': 55,
#  'cloud': 25,
#  'feelslike_c': 32.4,
#  'feelslike_f': 90.4,
#  'vis_km': 16.0,
#  'vis_miles': 9.0,
#  'uv': 6.0,
#  'gust_mph': 9.6,
#  'gust_kph': 15.5}

# %%
data['current']['wind_mph']
# Out:
# 11.9

# %%
print(f"The current wind speed in Pittsburgh is" , (data['current']['wind_mph']) , "miles per hour.")
# Out:
# The current wind speed in Pittsburgh is 11.9 miles per hour.

# %%
data['current']['feelslike_f']
# Out:
# 90.4

# %%
data['current']['temp_f']
# Out:
# 86.0

# %%
print(f"It feels" , (round((data['current']['feelslike_f'])-(data['current']['temp_f']))) , "degrees hotter than it is.")
# Out:
# It feels 4 degrees hotter than it is.

# %% [markdown]
# ## 3) What is the API endpoint for moon-related information? For the place you decided on above, how much of the moon will be visible on next Thursday?
#
# - *Tip: Check the documentation!*
# - *Tip: If you aren't sure what something means, ask in Slack*

# %%
pittsburgh_astronomy = requests.get ("http://api.weatherapi.com/v1/astronomy.json?key=a5a33e5547704451b06180649211906&q=Pittsburgh")
print(pittsburgh_astronomy.json())
# Out:
# {'location': {'name': 'Pittsburgh', 'region': 'Pennsylvania', 'country': 'United States of America', 'lat': 40.44, 'lon': -80.0, 'tz_id': 'America/New_York', 'localtime_epoch': 1624234921, 'localtime': '2021-06-20 20:22'}, 'astronomy': {'astro': {'sunrise': '05:50 AM', 'sunset': '08:54 PM', 'moonrise': '05:31 PM', 'moonset': '03:16 AM', 'moon_phase': 'Waxing Gibbous', 'moon_illumination': '79'}}}

# %%
pittsburgh_astronomy.json()['astronomy']
# Out:
# {'astro': {'sunrise': '05:50 AM',
#   'sunset': '08:54 PM',
#   'moonrise': '05:31 PM',
#   'moonset': '03:16 AM',
#   'moon_phase': 'Waxing Gibbous',
#   'moon_illumination': '79'}}

# %%
# come back to this ... how do you get info for future forecast?

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?
#
# - *Tip: When you requested moon data, you probably overwrote your variables! If so, you'll need to make a new request.*

# %%
pittsburgh_forecast = requests.get ("http://api.weatherapi.com/v1/forecast.json?key=a5a33e5547704451b06180649211906&q=Pittsburgh&days=7")
print(pittsburgh_forecast.json())
# Out:
# {'location': {'name': 'Pittsburgh', 'region': 'Pennsylvania', 'country': 'United States of America', 'lat': 40.44, 'lon': -80.0, 'tz_id': 'America/New_York', 'localtime_epoch': 1624228999, 'localtime': '2021-06-20 18:43'}, 'current': {'last_updated_epoch': 1624228200, 'last_updated': '2021-06-20 18:30', 'temp_c': 29.4, 'temp_f': 84.9, 'is_day': 1, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'wind_mph': 9.4, 'wind_kph': 15.1, 'wind_degree': 190, 'wind_dir': 'S', 'pressure_mb': 1008.0, 'pressure_in': 30.2, 'precip_mm': 0.8, 'precip_in': 0.03, 'humidity': 59, 'cloud': 25, 'feelslike_c': 31.6, 'feelslike_f': 88.8, 'vis_km': 14.0, 'vis_miles': 8.0, 'uv': 6.0, 'gust_mph': 10.7, 'gust_kph': 17.3}, 'forecast': {'forecastday': [{'date': '2021-06-20', 'date_epoch': 1624147200, 'day': {'maxtemp_c': 29.7, 'maxtemp_f': 85.5, 'mintemp_c': 16.5, 'mintemp_f': 61.7, 'avgtemp_c': 23.5, 'avgtemp_f': 74.4, 'maxwind_mph': 9.2, 'maxwind_kph': 14.8, 'totalprecip_mm': 6.9, 'totalprecip_in': 0.27, 'avgvis_km': 7.8, 'avgvis_miles': 4.0, 'avghumidity': 83.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': '76', 'daily_will_it_snow': 0, 'daily_chance_of_snow': '0', 'condition': {'text': 'Moderate rain', 'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png', 'code': 1189}, 'uv': 7.0}, 'astro': {'sunrise': '05:50 AM', 'sunset': '08:54 PM', 'moonrise': '04:14 PM', 'moonset': '02:45 AM', 'moon_phase': 'Full Moon', 'moon_illumination': '76'}, 'hour': [{'time_epoch': 1624161600, 'time': '2021-06-20 00:00', 'temp_c': 18.6, 'temp_f': 65.5, 'is_day': 0, 'condition': {'text': 'Fog', 'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png', 'code': 1135}, 'wind_mph': 5.4, 'wind_kph': 8.6, 'wind_degree': 230, 'wind_dir': 'SW', 'pressure_mb': 1009.0, 'pressure_in': 30.3, 'precip_mm': 1.6, 'precip_in': 0.06, 'humidity': 99, 'cloud': 67, 'feelslike_c': 18.6, 'feelslike_f': 65.5, 'windchill_c': 18.6, 'windchill_f': 65.5, 'heatindex_c': 18.6, 'heatindex_f': 65.5, 'dewpoint_c': 18.4, 'dewpoint_f': 65.1, 'will_it_rain': 0, 'chance_of_rain': '41', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 6.7, 'vis_miles': 4.0, 'gust_mph': 10.1, 'gust_kph': 16.2, 'uv': 1.0}, {'time_epoch': 1624165200, 'time': '2021-06-20 01:00', 'temp_c': 18.2, 'temp_f': 64.8, 'is_day': 0, 'condition': {'text': 'Light rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png', 'code': 1240}, 'wind_mph': 4.9, 'wind_kph': 7.9, 'wind_degree': 225, 'wind_dir': 'SW', 'pressure_mb': 1009.0, 'pressure_in': 30.3, 'precip_mm': 0.8, 'precip_in': 0.03, 'humidity': 99, 'cloud': 84, 'feelslike_c': 18.2, 'feelslike_f': 64.8, 'windchill_c': 18.2, 'windchill_f': 64.8, 'heatindex_c': 18.2, 'heatindex_f': 64.8, 'dewpoint_c': 18.0, 'dewpoint_f': 64.4, 'will_it_rain': 0, 'chance_of_rain': '20', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 3.3, 'vis_miles': 2.0, 'gust_mph': 9.4, 'gust_kph': 15.1, 'uv': 1.0}, {'time_epoch': 1624168800, 'time': '2021-06-20 02:00', 'temp_c': 17.8, 'temp_f': 64.0, 'is_day': 0, 'condition': {'text': 'Fog', 'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png', 'code': 1135}, 'wind_mph': 4.5, 'wind_kph': 7.2, 'wind_degree': 220, 'wind_dir': 'SW', 'pressure_mb': 1009.0, 'pressure_in': 30.3, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 99, 'cloud': 100, 'feelslike_c': 17.8, 'feelslike_f': 64.0, 'windchill_c': 17.8, 'windchill_f': 64.0, 'heatindex_c': 17.8, 'heatindex_f': 64.0, 'dewpoint_c': 17.7, 'dewpoint_f': 63.9, 'will_it_rain': 0, 'chance_of_rain': '0', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 0.0, 'vis_miles': 0.0, 'gust_mph': 8.9, 'gust_kph': 14.4, 'uv': 1.0}, {'time_epoch': 1624172400, 'time': '2021-06-20 03:00', 'temp_c': 17.4, 'temp_f': 63.3, 'is_day': 0, 'condition': {'text': 'Light rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png', 'code': 1240}, 'wind_mph': 4.3, 'wind_kph': 6.8, 'wind_degree': 213, 'wind_dir': 'SSW', 'pressure_mb': 1009.0, 'press ...

# %%
print(pittsburgh_forecast.json()['forecast'])
# Out:
# {'forecastday': [{'date': '2021-06-20', 'date_epoch': 1624147200, 'day': {'maxtemp_c': 29.7, 'maxtemp_f': 85.5, 'mintemp_c': 16.5, 'mintemp_f': 61.7, 'avgtemp_c': 23.5, 'avgtemp_f': 74.4, 'maxwind_mph': 9.2, 'maxwind_kph': 14.8, 'totalprecip_mm': 6.9, 'totalprecip_in': 0.27, 'avgvis_km': 7.8, 'avgvis_miles': 4.0, 'avghumidity': 83.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': '76', 'daily_will_it_snow': 0, 'daily_chance_of_snow': '0', 'condition': {'text': 'Moderate rain', 'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png', 'code': 1189}, 'uv': 7.0}, 'astro': {'sunrise': '05:50 AM', 'sunset': '08:54 PM', 'moonrise': '04:14 PM', 'moonset': '02:45 AM', 'moon_phase': 'Full Moon', 'moon_illumination': '76'}, 'hour': [{'time_epoch': 1624161600, 'time': '2021-06-20 00:00', 'temp_c': 18.6, 'temp_f': 65.5, 'is_day': 0, 'condition': {'text': 'Fog', 'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png', 'code': 1135}, 'wind_mph': 5.4, 'wind_kph': 8.6, 'wind_degree': 230, 'wind_dir': 'SW', 'pressure_mb': 1009.0, 'pressure_in': 30.3, 'precip_mm': 1.6, 'precip_in': 0.06, 'humidity': 99, 'cloud': 67, 'feelslike_c': 18.6, 'feelslike_f': 65.5, 'windchill_c': 18.6, 'windchill_f': 65.5, 'heatindex_c': 18.6, 'heatindex_f': 65.5, 'dewpoint_c': 18.4, 'dewpoint_f': 65.1, 'will_it_rain': 0, 'chance_of_rain': '41', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 6.7, 'vis_miles': 4.0, 'gust_mph': 10.1, 'gust_kph': 16.2, 'uv': 1.0}, {'time_epoch': 1624165200, 'time': '2021-06-20 01:00', 'temp_c': 18.2, 'temp_f': 64.8, 'is_day': 0, 'condition': {'text': 'Light rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png', 'code': 1240}, 'wind_mph': 4.9, 'wind_kph': 7.9, 'wind_degree': 225, 'wind_dir': 'SW', 'pressure_mb': 1009.0, 'pressure_in': 30.3, 'precip_mm': 0.8, 'precip_in': 0.03, 'humidity': 99, 'cloud': 84, 'feelslike_c': 18.2, 'feelslike_f': 64.8, 'windchill_c': 18.2, 'windchill_f': 64.8, 'heatindex_c': 18.2, 'heatindex_f': 64.8, 'dewpoint_c': 18.0, 'dewpoint_f': 64.4, 'will_it_rain': 0, 'chance_of_rain': '20', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 3.3, 'vis_miles': 2.0, 'gust_mph': 9.4, 'gust_kph': 15.1, 'uv': 1.0}, {'time_epoch': 1624168800, 'time': '2021-06-20 02:00', 'temp_c': 17.8, 'temp_f': 64.0, 'is_day': 0, 'condition': {'text': 'Fog', 'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png', 'code': 1135}, 'wind_mph': 4.5, 'wind_kph': 7.2, 'wind_degree': 220, 'wind_dir': 'SW', 'pressure_mb': 1009.0, 'pressure_in': 30.3, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 99, 'cloud': 100, 'feelslike_c': 17.8, 'feelslike_f': 64.0, 'windchill_c': 17.8, 'windchill_f': 64.0, 'heatindex_c': 17.8, 'heatindex_f': 64.0, 'dewpoint_c': 17.7, 'dewpoint_f': 63.9, 'will_it_rain': 0, 'chance_of_rain': '0', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 0.0, 'vis_miles': 0.0, 'gust_mph': 8.9, 'gust_kph': 14.4, 'uv': 1.0}, {'time_epoch': 1624172400, 'time': '2021-06-20 03:00', 'temp_c': 17.4, 'temp_f': 63.3, 'is_day': 0, 'condition': {'text': 'Light rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png', 'code': 1240}, 'wind_mph': 4.3, 'wind_kph': 6.8, 'wind_degree': 213, 'wind_dir': 'SSW', 'pressure_mb': 1009.0, 'pressure_in': 30.3, 'precip_mm': 0.6, 'precip_in': 0.02, 'humidity': 99, 'cloud': 86, 'feelslike_c': 17.4, 'feelslike_f': 63.3, 'windchill_c': 17.4, 'windchill_f': 63.3, 'heatindex_c': 17.4, 'heatindex_f': 63.3, 'dewpoint_c': 17.3, 'dewpoint_f': 63.1, 'will_it_rain': 0, 'chance_of_rain': '19', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 3.3, 'vis_miles': 2.0, 'gust_mph': 8.5, 'gust_kph': 13.7, 'uv': 1.0}, {'time_epoch': 1624176000, 'time': '2021-06-20 04:00', 'temp_c': 16.9, 'temp_f': 62.4, 'is_day': 0, 'condition': {'text': 'Fog', 'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png', 'code': 1135}, 'wind_mph': 3.8, 'wind_kph': 6.1, 'wind_degree': 207, 'wind_dir': 'SSW', 'pressure_mb': 1010.0, 'pressure_in': 30.3, 'precip_mm': 1.2, 'precip_in': 0.05, 'humidity' ...

# %%
pittsburgh_forecast.json()['forecast']['forecastday']
# Out:
# [{'date': '2021-06-20',
#   'date_epoch': 1624147200,
#   'day': {'maxtemp_c': 29.7,
#    'maxtemp_f': 85.5,
#    'mintemp_c': 16.5,
#    'mintemp_f': 61.7,
#    'avgtemp_c': 23.5,
#    'avgtemp_f': 74.4,
#    'maxwind_mph': 9.2,
#    'maxwind_kph': 14.8,
#    'totalprecip_mm': 6.9,
#    'totalprecip_in': 0.27,
#    'avgvis_km': 7.8,
#    'avgvis_miles': 4.0,
#    'avghumidity': 83.0,
#    'daily_will_it_rain': 1,
#    'daily_chance_of_rain': '76',
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': '0',
#    'condition': {'text': 'Moderate rain',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png',
#     'code': 1189},
#    'uv': 7.0},
#   'astro': {'sunrise': '05:50 AM',
#    'sunset': '08:54 PM',
#    'moonrise': '04:14 PM',
#    'moonset': '02:45 AM',
#    'moon_phase': 'Full Moon',
#    'moon_illumination': '76'},
#   'hour': [{'time_epoch': 1624161600,
#     'time': '2021-06-20 00:00',
#     'temp_c': 18.6,
#     'temp_f': 65.5,
#     'is_day': 0,
#     'condition': {'text': 'Fog',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png',
#      'code': 1135},
#     'wind_mph': 5.4,
#     'wind_kph': 8.6,
#     'wind_degree': 230,
#     'wind_dir': 'SW',
#     'pressure_mb': 1009.0,
#     'pressure_in': 30.3,
#     'precip_mm': 1.6,
#     'precip_in': 0.06,
#     'humidity': 99,
#     'cloud': 67,
#     'feelslike_c': 18.6,
#     'feelslike_f': 65.5,
#     'windchill_c': 18.6,
#     'windchill_f': 65.5,
#     'heatindex_c': 18.6,
#     'heatindex_f': 65.5,
#     'dewpoint_c': 18.4,
#     'dewpoint_f': 65.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '41',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 6.7,
#     'vis_miles': 4.0,
#     'gust_mph': 10.1,
#     'gust_kph': 16.2,
#     'uv': 1.0},
#    {'time_epoch': 1624165200,
#     'time': '2021-06-20 01:00',
#     'temp_c': 18.2,
#     'temp_f': 64.8,
#     'is_day': 0,
#     'condition': {'text': 'Light rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#      'code': 1240},
#     'wind_mph': 4.9,
#     'wind_kph': 7.9,
#     'wind_degree': 225,
#     'wind_dir': 'SW',
#     'pressure_mb': 1009.0,
#     'pressure_in': 30.3,
#     'precip_mm': 0.8,
#     'precip_in': 0.03,
#     'humidity': 99,
#     'cloud': 84,
#     'feelslike_c': 18.2,
#     'feelslike_f': 64.8,
#     'windchill_c': 18.2,
#     'windchill_f': 64.8,
#     'heatindex_c': 18.2,
#     'heatindex_f': 64.8,
#     'dewpoint_c': 18.0,
#     'dewpoint_f': 64.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '20',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 3.3,
#     'vis_miles': 2.0,
#     'gust_mph': 9.4,
#     'gust_kph': 15.1,
#     'uv': 1.0},
#    {'time_epoch': 1624168800,
#     'time': '2021-06-20 02:00',
#     'temp_c': 17.8,
#     'temp_f': 64.0,
#     'is_day': 0,
#     'condition': {'text': 'Fog',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png',
#      'code': 1135},
#     'wind_mph': 4.5,
#     'wind_kph': 7.2,
#     'wind_degree': 220,
#     'wind_dir': 'SW',
#     'pressure_mb': 1009.0,
#     'pressure_in': 30.3,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 99,
#     'cloud': 100,
#     'feelslike_c': 17.8,
#     'feelslike_f': 64.0,
#     'windchill_c': 17.8,
#     'windchill_f': 64.0,
#     'heatindex_c': 17.8,
#     'heatindex_f': 64.0,
#     'dewpoint_c': 17.7,
#     'dewpoint_f': 63.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 0.0,
#     'vis_miles': 0.0,
#     'gust_mph': 8.9,
#     'gust_kph': 14.4,
#     'uv': 1.0},
#    {'time_epoch': 1624172400,
#     'time': '2021-06-20 03:00',
#     'temp_c': 17.4,
#     'temp_f': 63.3,
#     'is_day': 0,
#     'condition': {'text': 'Light rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#      'code': 1240},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 213,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1009.0,
#     'pressure_in': 30.3,
#     'precip_mm': 0.6,
#     'precip_in': 0.02,
#     'humidity': 99,
#     'cloud': 86,
#     'feelslike_c': 17.4,
#     'feelslike_f': 63.3,
#     'windchill_c': 17.4,
#     'windchill_f': 63.3,
#     'heatindex_c': 17.4,
#     'heatindex_f': 63.3,
#     'dewpoint_c': 17.3,
#     'dewpoint_f': 63.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '19',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 3.3,
#     'vis_miles': 2.0,
#     'gust_mph': 8.5,
#     'gust_kph': 13.7,
#     'uv': 1.0},
#    {'time_epoch': 1624176000,
#     'time': '2021-06-20 04:00',
#     'temp_c': 16.9,
#     'temp_f': 62.4,
#     'is_day': 0,
#     'condition': {'text': 'Fog',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png',
#      'code': 1135},
#     'wind_mph': 3.8,
#     'wind_kph': 6.1,
#     'wind_degree': 207,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1010.0,
#     'pressure_in': 30.3,
#     'precip_mm': 1.2,
#     'precip_in': 0.05,
#     'humidity': 99,
#     'cloud': 72,
#     'feelslike_c': 16.9,
#     'feelslike_f': 62.4,
#     'windchill_c': 16.9,
#     'windchill_f': 62.4,
#     'heatindex_c': 16.9,
#     'heatindex_f': 62.4,
#     'dewpoint_c': 16.8,
#     'dewpoint_f': 62.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '39',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 6.7,
#     'vis_miles': 4.0,
#     'gust_mph': 7.8,
#     'gust_kph': 12.6,
#     'uv': 1.0},
#    {'time_epoch': 1624179600,
#     'time': '2021-06-20 05:00',
#     'temp_c': 16.5,
#     'temp_f': 61.7,
#     'is_day': 0,
#     'condition': {'text': 'Light rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#      'code': 1240},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 200,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1010.0,
#     'pressure_in': 30.3,
#     'precip_mm': 1.8,
#     'precip_in': 0.07,
#     'humidity': 99,
#     'cloud': 58,
#     'feelslike_c': 16.5,
#     'feelslike_f': 61.7,
#     'windchill_c': 16.5,
#     'windchill_f': 61.7,
#     'heatindex_c': 16.5,
#     'heatindex_f': 61.7,
#     'dewpoint_c': 16.4,
#     'dewpoint_f': 61.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '58',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.4,
#     'gust_kph': 11.9,
#     'uv': 1.0},
#    {'time_epoch': 1624183200,
#     'time': '2021-06-20 06:00',
#     'temp_c': 17.5,
#     'temp_f': 63.5,
#     'is_day': 1,
#     'condition': {'text': 'Moderate or heavy rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/356.png',
#      'code': 1243},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 202,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1010.0,
#     'pressure_in': 30.3,
#     'precip_mm': 2.4,
#     'precip_in': 0.09,
#     'humidity': 99,
#     'cloud': 63,
#     'feelslike_c': 17.5,
#     'feelslike_f': 63.5,
#     'windchill_c': 17.5,
#     'windchill_f': 63.5,
#     'heatindex_c': 17.5,
#     'heatindex_f': 63.5,
#     'dewpoint_c': 17.3,
#     'dewpoint_f': 63.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '62',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 9.0,
#     'vis_miles': 5.0,
#     'gust_mph': 7.8,
#     'gust_kph': 12.6,
#     'uv': 4.0},
#    {'time_epoch': 1624186800,
#     'time': '2021-06-20 07:00',
#     'temp_c': 18.6,
#     'temp_f': 65.5,
#     'is_day': 1,
#     'condition': {'text': 'Light rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#      'code': 1240},
#     'wind_mph': 4.5,
#     'wind_kph': 7.2,
#     'wind_degree': 204,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1011.0,
#     'pressure_in': 30.3,
#     'precip_mm': 3.0,
#     'precip_in': 0.12,
#     'humidity': 98,
#     'cloud': 69,
#     'feelslike_c': 18.6,
#     'feelslike_f': 65.5,
#     'windchill_c': 18.6,
#     'windchill_f': 65.5,
#     'heatindex_c': 18.6,
#     'heatindex_f': 65.5,
#     'dewpoint_c': 18.3,
#     'dewpoint_f': 64.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '65',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 8.0,
#     'vis_miles': 4.0,
#     'gust_mph': 8.1,
#     'gust_kph': 13.0,
#     'uv': 4.0},
#    {'time_epoch': 1624190400,
#     'time': '2021-06-20 08:00',
#     'temp_c': 19.6,
#     'temp_f': 67.3,
#     'is_day': 1,
#     'condition': {'text': 'Moderate or heavy rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/356.png',
#      'code': 1243},
#     'wind_mph': 4.9,
#     'wind_kph': 7.9,
#     'wind_degree': 205,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1011.0,
#     'pressure_in': 30.3,
#     'precip_mm': 3.6,
#     'precip_in': 0.14,
#     'humidity': 98,
#     'cloud': 74,
#     'feelslike_c': 19.6,
#     'feelslike_f': 67.3,
#     'windchill_c': 19.6,
#     'windchill_f': 67.3,
#     'heatindex_c': 19.6,
#     'heatindex_f': 67.3,
#     'dewpoint_c': 19.2,
#     'dewpoint_f': 66.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '69',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 7.0,
#     'vis_miles': 4.0,
#     'gust_mph': 8.5,
#     'gust_kph': 13.7,
#     'uv': 4.0},
#    {'time_epoch': 1624194000,
#     'time': '2021-06-20 09:00',
#     'temp_c': 21.4,
#     'temp_f': 70.5,
#     'is_day': 1,
#     'condition': {'text': 'Light rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#      'code': 1240},
#     'wind_mph': 6.0,
#     'wind_kph': 9.7,
#     'wind_degree': 210,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1011.0,
#     'pressure_in': 30.3,
#     'precip_mm': 2.8,
#     'precip_in': 0.11,
#     'humidity': 93,
#     'cloud': 76,
#     'feelslike_c': 21.4,
#     'feelslike_f': 70.5,
#     'windchill_c': 21.4,
#     'windchill_f': 70.5,
#     'heatindex_c': 22.1,
#     'heatindex_f': 71.8,
#     'dewpoint_c': 20.2,
#     'dewpoint_f': 68.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '68',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 8.0,
#     'vis_miles': 4.0,
#     'gust_mph': 9.4,
#     'gust_kph': 15.1,
#     'uv': 5.0},
#    {'time_epoch': 1624197600,
#     'time': '2021-06-20 10:00',
#     'temp_c': 23.1,
#     'temp_f': 73.6,
#     'is_day': 1,
#     'condition': {'text': 'Moderate or heavy rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/356.png',
#      'code': 1243},
#     'wind_mph': 7.4,
#     'wind_kph': 11.9,
#     'wind_degree': 214,
#     'wind_dir': 'SW',
#     'pressure_mb': 1010.0,
#     'pressure_in': 30.3,
#     'precip_mm': 1.9,
#     'precip_in': 0.07,
#     'humidity': 89,
#     'cloud': 77,
#     'feelslike_c': 24.7,
#     'feelslike_f': 76.5,
#     'windchill_c': 23.1,
#     'windchill_f': 73.6,
#     'heatindex_c': 24.7,
#     'heatindex_f': 76.5,
#     'dewpoint_c': 21.1,
#     'dewpoint_f': 70.0,
#     'will_it_rain': 0,
#     'chance_of_rain': '66',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 9.0,
#     'vis_miles': 5.0,
#     'gust_mph': 10.5,
#     'gust_kph': 16.9,
#     'uv': 5.0},
#    {'time_epoch': 1624201200,
#     'time': '2021-06-20 11:00',
#     'temp_c': 24.9,
#     'temp_f': 76.8,
#     'is_day': 1,
#     'condition': {'text': 'Light rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#      'code': 1240},
#     'wind_mph': 8.5,
#     'wind_kph': 13.7,
#     'wind_degree': 218,
#     'wind_dir': 'SW',
#     'pressure_mb': 1010.0,
#     'pressure_in': 30.3,
#     'precip_mm': 1.1,
#     'precip_in': 0.04,
#     'humidity': 84,
#     'cloud': 79,
#     'feelslike_c': 27.2,
#     'feelslike_f': 81.0,
#     'windchill_c': 24.9,
#     'windchill_f': 76.8,
#     'heatindex_c': 27.2,
#     'heatindex_f': 81.0,
#     'dewpoint_c': 22.1,
#     'dewpoint_f': 71.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '65',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.4,
#     'gust_kph': 18.4,
#     'uv': 5.0},
#    {'time_epoch': 1624204800,
#     'time': '2021-06-20 12:00',
#     'temp_c': 26.4,
#     'temp_f': 79.5,
#     'is_day': 1,
#     'condition': {'text': 'Light rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#      'code': 1240},
#     'wind_mph': 8.9,
#     'wind_kph': 14.4,
#     'wind_degree': 225,
#     'wind_dir': 'SW',
#     'pressure_mb': 1009.0,
#     'pressure_in': 30.3,
#     'precip_mm': 1.1,
#     'precip_in': 0.04,
#     'humidity': 75,
#     'cloud': 81,
#     'feelslike_c': 28.6,
#     'feelslike_f': 83.5,
#     'windchill_c': 26.4,
#     'windchill_f': 79.5,
#     'heatindex_c': 28.6,
#     'heatindex_f': 83.5,
#     'dewpoint_c': 21.3,
#     'dewpoint_f': 70.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '67',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.9,
#     'gust_kph': 19.1,
#     'uv': 6.0},
#    {'time_epoch': 1624208400,
#     'time': '2021-06-20 13:00',
#     'temp_c': 27.8,
#     'temp_f': 82.0,
#     'is_day': 1,
#     'condition': {'text': 'Light rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#      'code': 1240},
#     'wind_mph': 9.2,
#     'wind_kph': 14.8,
#     'wind_degree': 231,
#     'wind_dir': 'SW',
#     'pressure_mb': 1009.0,
#     'pressure_in': 30.3,
#     'precip_mm': 1.1,
#     'precip_in': 0.04,
#     'humidity': 66,
#     'cloud': 83,
#     'feelslike_c': 29.9,
#     'feelslike_f': 85.8,
#     'windchill_c': 27.8,
#     'windchill_f': 82.0,
#     'heatindex_c': 29.9,
#     'heatindex_f': 85.8,
#     'dewpoint_c': 20.6,
#     'dewpoint_f': 69.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '68',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.3,
#     'gust_kph': 19.8,
#     'uv': 6.0},
#    {'time_epoch': 1624212000,
#     'time': '2021-06-20 14:00',
#     'temp_c': 29.3,
#     'temp_f': 84.7,
#     'is_day': 1,
#     'condition': {'text': 'Light rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#      'code': 1240},
#     'wind_mph': 9.6,
#     'wind_kph': 15.5,
#     'wind_degree': 238,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1008.0,
#     'pressure_in': 30.2,
#     'precip_mm': 1.1,
#     'precip_in': 0.04,
#     'humidity': 57,
#     'cloud': 85,
#     'feelslike_c': 31.3,
#     'feelslike_f': 88.3,
#     'windchill_c': 29.3,
#     'windchill_f': 84.7,
#     'heatindex_c': 31.3,
#     'heatindex_f': 88.3,
#     'dewpoint_c': 19.8,
#     'dewpoint_f': 67.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '70',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.8,
#     'gust_kph': 20.5,
#     'uv': 6.0},
#    {'time_epoch': 1624215600,
#     'time': '2021-06-20 15:00',
#     'temp_c': 29.5,
#     'temp_f': 85.1,
#     'is_day': 1,
#     'condition': {'text': 'Patchy light rain with thunder',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#      'code': 1273},
#     'wind_mph': 8.3,
#     'wind_kph': 13.3,
#     'wind_degree': 246,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1007.0,
#     'pressure_in': 30.2,
#     'precip_mm': 0.8,
#     'precip_in': 0.03,
#     'humidity': 57,
#     'cloud': 83,
#     'feelslike_c': 31.8,
#     'feelslike_f': 89.2,
#     'windchill_c': 29.5,
#     'windchill_f': 85.1,
#     'heatindex_c': 31.8,
#     'heatindex_f': 89.2,
#     'dewpoint_c': 20.2,
#     'dewpoint_f': 68.4,
#     'will_it_rain': 1,
#     'chance_of_rain': '74',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 10.7,
#     'gust_kph': 17.3,
#     'uv': 6.0},
#    {'time_epoch': 1624219200,
#     'time': '2021-06-20 16:00',
#     'temp_c': 29.8,
#     'temp_f': 85.6,
#     'is_day': 1,
#     'condition': {'text': 'Light rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#      'code': 1240},
#     'wind_mph': 6.9,
#     'wind_kph': 11.2,
#     'wind_degree': 255,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1007.0,
#     'pressure_in': 30.2,
#     'precip_mm': 0.6,
#     'precip_in': 0.02,
#     'humidity': 58,
#     'cloud': 81,
#     'feelslike_c': 32.3,
#     'feelslike_f': 90.1,
#     'windchill_c': 29.8,
#     'windchill_f': 85.6,
#     'heatindex_c': 32.3,
#     'heatindex_f': 90.1,
#     'dewpoint_c': 20.5,
#     'dewpoint_f': 68.9,
#     'will_it_rain': 1,
#     'chance_of_rain': '78',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.7,
#     'gust_kph': 14.0,
#     'uv': 6.0},
#    {'time_epoch': 1624222800,
#     'time': '2021-06-20 17:00',
#     'temp_c': 30.0,
#     'temp_f': 86.0,
#     'is_day': 1,
#     'condition': {'text': 'Patchy light rain with thunder',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#      'code': 1273},
#     'wind_mph': 5.6,
#     'wind_kph': 9.0,
#     'wind_degree': 263,
#     'wind_dir': 'W',
#     'pressure_mb': 1006.0,
#     'pressure_in': 30.2,
#     'precip_mm': 0.3,
#     'precip_in': 0.01,
#     'humidity': 58,
#     'cloud': 79,
#     'feelslike_c': 32.8,
#     'feelslike_f': 91.0,
#     'windchill_c': 30.0,
#     'windchill_f': 86.0,
#     'heatindex_c': 32.8,
#     'heatindex_f': 91.0,
#     'dewpoint_c': 20.9,
#     'dewpoint_f': 69.6,
#     'will_it_rain': 1,
#     'chance_of_rain': '82',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.7,
#     'gust_kph': 10.8,
#     'uv': 7.0},
#    {'time_epoch': 1624226400,
#     'time': '2021-06-20 18:00',
#     'temp_c': 28.7,
#     'temp_f': 83.7,
#     'is_day': 1,
#     'condition': {'text': 'Patchy light rain with thunder',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#      'code': 1273},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 271,
#     'wind_dir': 'W',
#     'pressure_mb': 1006.0,
#     'pressure_in': 30.2,
#     'precip_mm': 0.3,
#     'precip_in': 0.01,
#     'humidity': 68,
#     'cloud': 77,
#     'feelslike_c': 31.2,
#     'feelslike_f': 88.2,
#     'windchill_c': 28.7,
#     'windchill_f': 83.7,
#     'heatindex_c': 31.2,
#     'heatindex_f': 88.2,
#     'dewpoint_c': 21.3,
#     'dewpoint_f': 70.3,
#     'will_it_rain': 1,
#     'chance_of_rain': '79',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.8,
#     'gust_kph': 9.4,
#     'uv': 6.0},
#    {'time_epoch': 1624230000,
#     'time': '2021-06-20 19:00',
#     'temp_c': 27.3,
#     'temp_f': 81.1,
#     'is_day': 1,
#     'condition': {'text': 'Patchy light rain with thunder',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#      'code': 1273},
#     'wind_mph': 3.1,
#     'wind_kph': 5.0,
#     'wind_degree': 279,
#     'wind_dir': 'W',
#     'pressure_mb': 1006.0,
#     'pressure_in': 30.2,
#     'precip_mm': 0.4,
#     'precip_in': 0.02,
#     'humidity': 77,
#     'cloud': 74,
#     'feelslike_c': 29.6,
#     'feelslike_f': 85.3,
#     'windchill_c': 27.3,
#     'windchill_f': 81.1,
#     'heatindex_c': 29.6,
#     'heatindex_f': 85.3,
#     'dewpoint_c': 21.8,
#     'dewpoint_f': 71.2,
#     'will_it_rain': 1,
#     'chance_of_rain': '75',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.7,
#     'gust_kph': 7.6,
#     'uv': 6.0},
#    {'time_epoch': 1624233600,
#     'time': '2021-06-20 20:00',
#     'temp_c': 26.0,
#     'temp_f': 78.8,
#     'is_day': 1,
#     'condition': {'text': 'Patchy light rain with thunder',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#      'code': 1273},
#     'wind_mph': 1.8,
#     'wind_kph': 2.9,
#     'wind_degree': 286,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1006.0,
#     'pressure_in': 30.2,
#     'precip_mm': 0.4,
#     'precip_in': 0.02,
#     'humidity': 87,
#     'cloud': 72,
#     'feelslike_c': 28.0,
#     'feelslike_f': 82.4,
#     'windchill_c': 26.0,
#     'windchill_f': 78.8,
#     'heatindex_c': 28.0,
#     'heatindex_f': 82.4,
#     'dewpoint_c': 22.2,
#     'dewpoint_f': 72.0,
#     'will_it_rain': 1,
#     'chance_of_rain': '72',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.8,
#     'gust_kph': 6.1,
#     'uv': 6.0},
#    {'time_epoch': 1624237200,
#     'time': '2021-06-20 21:00',
#     'temp_c': 24.5,
#     'temp_f': 76.1,
#     'is_day': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#      'code': 1063},
#     'wind_mph': 2.2,
#     'wind_kph': 3.6,
#     'wind_degree': 253,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1006.0,
#     'pressure_in': 30.2,
#     'precip_mm': 0.3,
#     'precip_in': 0.01,
#     'humidity': 89,
#     'cloud': 73,
#     'feelslike_c': 26.7,
#     'feelslike_f': 80.1,
#     'windchill_c': 24.5,
#     'windchill_f': 76.1,
#     'heatindex_c': 26.7,
#     'heatindex_f': 80.1,
#     'dewpoint_c': 21.6,
#     'dewpoint_f': 70.9,
#     'will_it_rain': 1,
#     'chance_of_rain': '73',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 9.7,
#     'vis_miles': 6.0,
#     'gust_mph': 4.9,
#     'gust_kph': 7.9,
#     'uv': 1.0},
#    {'time_epoch': 1624240800,
#     'time': '2021-06-20 22:00',
#     'temp_c': 22.9,
#     'temp_f': 73.2,
#     'is_day': 0,
#     'condition': {'text': 'Patchy light rain with thunder',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/386.png',
#      'code': 1273},
#     'wind_mph': 2.9,
#     'wind_kph': 4.7,
#     'wind_degree': 220,
#     'wind_dir': 'SW',
#     'pressure_mb': 1006.0,
#     'pressure_in': 30.2,
#     'precip_mm': 0.3,
#     'precip_in': 0.01,
#     'humidity': 92,
#     'cloud': 73,
#     'feelslike_c': 25.5,
#     'feelslike_f': 77.9,
#     'windchill_c': 22.9,
#     'windchill_f': 73.2,
#     'heatindex_c': 25.5,
#     'heatindex_f': 77.9,
#     'dewpoint_c': 21.0,
#     'dewpoint_f': 69.8,
#     'will_it_rain': 1,
#     'chance_of_rain': '75',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 9.3,
#     'vis_miles': 5.0,
#     'gust_mph': 5.8,
#     'gust_kph': 9.4,
#     'uv': 1.0},
#    {'time_epoch': 1624244400,
#     'time': '2021-06-20 23:00',
#     'temp_c': 21.4,
#     'temp_f': 70.5,
#     'is_day': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#      'code': 1063},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 187,
#     'wind_dir': 'S',
#     'pressure_mb': 1006.0,
#     'pressure_in': 30.2,
#     'precip_mm': 0.2,
#     'precip_in': 0.01,
#     'humidity': 94,
#     'cloud': 74,
#     'feelslike_c': 21.4,
#     'feelslike_f': 70.5,
#     'windchill_c': 21.4,
#     'windchill_f': 70.5,
#     'heatindex_c': 24.2,
#     'heatindex_f': 75.6,
#     'dewpoint_c': 20.4,
#     'dewpoint_f': 68.7,
#     'will_it_rain': 1,
#     'chance_of_rain': '76',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 9.0,
#     'vis_miles': 5.0,
#     'gust_mph': 6.9,
#     'gust_kph': 11.2,
#     'uv': 1.0}]},
#  {'date': '2021-06-21',
#   'date_epoch': 1624233600,
#   'day': {'maxtemp_c': 27.5,
#    'maxtemp_f': 81.5,
#    'mintemp_c': 19.0,
#    'mintemp_f': 66.2,
#    'avgtemp_c': 22.3,
#    'avgtemp_f': 72.2,
#    'maxwind_mph': 12.5,
#    'maxwind_kph': 20.2,
#    'totalprecip_mm': 10.1,
#    'totalprecip_in': 0.4,
#    'avgvis_km': 9.0,
#    'avgvis_miles': 5.0,
#    'avghumidity': 91.0,
#    'daily_will_it_rain': 1,
#    'daily_chance_of_rain': '87',
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': '0',
#    'condition': {'text': 'Moderate rain',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png',
#     'code': 1189},
#    'uv': 8.0},
#   'astro': {'sunrise': '05:50 AM',
#    'sunset': '08:54 PM',
#    'moonrise': '05:31 PM',
#    'moonset': '03:16 AM',
#    'moon_phase': 'Full Moon',
#    'moon_illumination': '83'},
#   'hour': [{'time_epoch': 1624248000,
#     'time': '2021-06-21 00:00',
#     'temp_c': 20.7,
#     'temp_f': 69.3,
#     'is_day': 0,
#     'condition': {'text': 'Moderate or heavy rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/356.png',
#      'code': 1243},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 193,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1006.0,
#     'pressure_in': 30.2,
#     'precip_mm': 1.2,
#     'precip_in': 0.05,
#     'humidity': 96,
#     'cloud': 69,
#     'feelslike_c': 20.7,
#     'feelslike_f': 69.3,
#     'windchill_c': 20.7,
#     'windchill_f': 69.3,
#     'heatindex_c': 22.6,
#     'heatindex_f': 72.7,
#     'dewpoint_c': 19.9,
#     'dewpoint_f': 67.8,
#     'will_it_rain': 1,
#     'chance_of_rain': '73',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 8.3,
#     'vis_miles': 5.0,
#     'gust_mph': 7.4,
#     'gust_kph': 11.9,
#     'uv': 1.0},
#    {'time_epoch': 1624251600,
#     'time': '2021-06-21 01:00',
#     'temp_c': 20.0,
#     'temp_f': 68.0,
#     'is_day': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#      'code': 1063},
#     'wind_mph': 3.8,
#     'wind_kph': 6.1,
#     'wind_degree': 199,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1006.0,
#     'pressure_in': 30.2,
#     'precip_mm': 2.1,
#     'precip_in': 0.08,
#     'humidity': 97,
#     'cloud': 63,
#     'feelslike_c': 20.0,
#     'feelslike_f': 68.0,
#     'windchill_c': 20.0,
#     'windchill_f': 68.0,
#     'heatindex_c': 20.9,
#     'heatindex_f': 69.6,
#     'dewpoint_c': 19.5,
#     'dewpoint_f': 67.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '70',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 7.7,
#     'vis_miles': 4.0,
#     'gust_mph': 8.1,
#     'gust_kph': 13.0,
#     'uv': 1.0},
#    {'time_epoch': 1624255200,
#     'time': '2021-06-21 02:00',
#     'temp_c': 19.3,
#     'temp_f': 66.7,
#     'is_day': 0,
#     'condition': {'text': 'Moderate or heavy rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/356.png',
#      'code': 1243},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 205,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1006.0,
#     'pressure_in': 30.2,
#     'precip_mm': 3.1,
#     'precip_in': 0.12,
#     'humidity': 98,
#     'cloud': 58,
#     'feelslike_c': 19.3,
#     'feelslike_f': 66.7,
#     'windchill_c': 19.3,
#     'windchill_f': 66.7,
#     'heatindex_c': 19.3,
#     'heatindex_f': 66.7,
#     'dewpoint_c': 19.0,
#     'dewpoint_f': 66.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '67',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 7.0,
#     'vis_miles': 4.0,
#     'gust_mph': 8.5,
#     'gust_kph': 13.7,
#     'uv': 1.0},
#    {'time_epoch': 1624258800,
#     'time': '2021-06-21 03:00',
#     'temp_c': 19.1,
#     'temp_f': 66.4,
#     'is_day': 0,
#     'condition': {'text': 'Moderate or heavy rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/356.png',
#      'code': 1243},
#     'wind_mph': 4.5,
#     'wind_kph': 7.2,
#     'wind_degree': 199,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1006.0,
#     'pressure_in': 30.2,
#     'precip_mm': 3.2,
#     'precip_in': 0.13,
#     'humidity': 98,
#     'cloud': 59,
#     'feelslike_c': 19.1,
#     'feelslike_f': 66.4,
#     'windchill_c': 19.1,
#     'windchill_f': 66.4,
#     'heatindex_c': 19.1,
#     'heatindex_f': 66.4,
#     'dewpoint_c': 18.8,
#     'dewpoint_f': 65.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '65',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 7.0,
#     'vis_miles': 4.0,
#     'gust_mph': 9.4,
#     'gust_kph': 15.1,
#     'uv': 1.0},
#    {'time_epoch': 1624262400,
#     'time': '2021-06-21 04:00',
#     'temp_c': 18.9,
#     'temp_f': 66.0,
#     'is_day': 0,
#     'condition': {'text': 'Moderate or heavy rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/356.png',
#      'code': 1243},
#     'wind_mph': 5.1,
#     'wind_kph': 8.3,
#     'wind_degree': 193,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1006.0,
#     'pressure_in': 30.2,
#     'precip_mm': 3.3,
#     'precip_in': 0.13,
#     'humidity': 98,
#     'cloud': 60,
#     'feelslike_c': 18.9,
#     'feelslike_f': 66.0,
#     'windchill_c': 18.9,
#     'windchill_f': 66.0,
#     'heatindex_c': 18.9,
#     'heatindex_f': 66.0,
#     'dewpoint_c': 18.7,
#     'dewpoint_f': 65.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '64',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 7.0,
#     'vis_miles': 4.0,
#     'gust_mph': 10.3,
#     'gust_kph': 16.6,
#     'uv': 1.0},
#    {'time_epoch': 1624266000,
#     'time': '2021-06-21 05:00',
#     'temp_c': 18.7,
#     'temp_f': 65.7,
#     'is_day': 0,
#     'condition': {'text': 'Moderate or heavy rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/356.png',
#      'code': 1243},
#     'wind_mph': 5.6,
#     'wind_kph': 9.0,
#     'wind_degree': 187,
#     'wind_dir': 'S',
#     'pressure_mb': 1006.0,
#     'pressure_in': 30.2,
#     'precip_mm': 3.4,
#     'precip_in': 0.13,
#     'humidity': 99,
#     'cloud': 61,
#     'feelslike_c': 18.7,
#     'feelslike_f': 65.7,
#     'windchill_c': 18.7,
#     'windchill_f': 65.7,
#     'heatindex_c': 18.7,
#     'heatindex_f': 65.7,
#     'dewpoint_c': 18.5,
#     'dewpoint_f': 65.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '62',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 7.0,
#     'vis_miles': 4.0,
#     'gust_mph': 11.2,
#     'gust_kph': 18.0,
#     'uv': 1.0},
#    {'time_epoch': 1624269600,
#     'time': '2021-06-21 06:00',
#     'temp_c': 19.4,
#     'temp_f': 66.9,
#     'is_day': 1,
#     'condition': {'text': 'Moderate or heavy rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/356.png',
#      'code': 1243},
#     'wind_mph': 6.5,
#     'wind_kph': 10.4,
#     'wind_degree': 188,
#     'wind_dir': 'S',
#     'pressure_mb': 1005.0,
#     'pressure_in': 30.2,
#     'precip_mm': 3.1,
#     'precip_in': 0.12,
#     'humidity': 98,
#     'cloud': 58,
#     'feelslike_c': 19.4,
#     'feelslike_f': 66.9,
#     'windchill_c': 19.4,
#     'windchill_f': 66.9,
#     'heatindex_c': 19.4,
#     'heatindex_f': 66.9,
#     'dewpoint_c': 19.1,
#     'dewpoint_f': 66.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '65',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 7.0,
#     'vis_miles': 4.0,
#     'gust_mph': 11.9,
#     'gust_kph': 19.1,
#     'uv': 4.0},
#    {'time_epoch': 1624273200,
#     'time': '2021-06-21 07:00',
#     'temp_c': 20.2,
#     'temp_f': 68.4,
#     'is_day': 1,
#     'condition': {'text': 'Moderate or heavy rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/356.png',
#      'code': 1243},
#     'wind_mph': 7.2,
#     'wind_kph': 11.5,
#     'wind_degree': 189,
#     'wind_dir': 'S',
#     'pressure_mb': 1005.0,
#     'pressure_in': 30.2,
#     'precip_mm': 2.9,
#     'precip_in': 0.11,
#     'humidity': 97,
#     'cloud': 54,
#     'feelslike_c': 20.2,
#     'feelslike_f': 68.4,
#     'windchill_c': 20.2,
#     'windchill_f': 68.4,
#     'heatindex_c': 20.2,
#     'heatindex_f': 68.4,
#     'dewpoint_c': 19.7,
#     'dewpoint_f': 67.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '69',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 7.0,
#     'vis_miles': 4.0,
#     'gust_mph': 12.3,
#     'gust_kph': 19.8,
#     'uv': 5.0},
#    {'time_epoch': 1624276800,
#     'time': '2021-06-21 08:00',
#     'temp_c': 20.9,
#     'temp_f': 69.6,
#     'is_day': 1,
#     'condition': {'text': 'Moderate or heavy rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/356.png',
#      'code': 1243},
#     'wind_mph': 8.1,
#     'wind_kph': 13.0,
#     'wind_degree': 189,
#     'wind_dir': 'S',
#     'pressure_mb': 1005.0,
#     'pressure_in': 30.1,
#     'precip_mm': 2.6,
#     'precip_in': 0.1,
#     'humidity': 96,
#     'cloud': 51,
#     'feelslike_c': 20.9,
#     'feelslike_f': 69.6,
#     'windchill_c': 20.9,
#     'windchill_f': 69.6,
#     'heatindex_c': 20.9,
#     'heatindex_f': 69.6,
#     'dewpoint_c': 20.3,
#     'dewpoint_f': 68.5,
#     'will_it_rain': 1,
#     'chance_of_rain': '72',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 7.0,
#     'vis_miles': 4.0,
#     'gust_mph': 13.0,
#     'gust_kph': 20.9,
#     'uv': 5.0},
#    {'time_epoch': 1624280400,
#     'time': '2021-06-21 09:00',
#     'temp_c': 23.0,
#     'temp_f': 73.4,
#     'is_day': 1,
#     'condition': {'text': 'Patchy light rain with thunder',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#      'code': 1273},
#     'wind_mph': 9.4,
#     'wind_kph': 15.1,
#     'wind_degree': 200,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1004.0,
#     'pressure_in': 30.1,
#     'precip_mm': 1.8,
#     'precip_in': 0.07,
#     'humidity': 87,
#     'cloud': 60,
#     'feelslike_c': 23.8,
#     'feelslike_f': 74.8,
#     'windchill_c': 23.0,
#     'windchill_f': 73.4,
#     'heatindex_c': 23.8,
#     'heatindex_f': 74.8,
#     'dewpoint_c': 20.6,
#     'dewpoint_f': 69.1,
#     'will_it_rain': 1,
#     'chance_of_rain': '73',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 8.0,
#     'vis_miles': 4.0,
#     'gust_mph': 13.4,
#     'gust_kph': 21.6,
#     'uv': 5.0},
#    {'time_epoch': 1624284000,
#     'time': '2021-06-21 10:00',
#     'temp_c': 25.2,
#     'temp_f': 77.4,
#     'is_day': 1,
#     'condition': {'text': 'Moderate or heavy rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/356.png',
#      'code': 1243},
#     'wind_mph': 10.7,
#     'wind_kph': 17.3,
#     'wind_degree': 210,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1004.0,
#     'pressure_in': 30.1,
#     'precip_mm': 1.1,
#     'precip_in': 0.04,
#     'humidity': 78,
#     'cloud': 69,
#     'feelslike_c': 26.8,
#     'feelslike_f': 80.2,
#     'windchill_c': 25.2,
#     'windchill_f': 77.4,
#     'heatindex_c': 26.8,
#     'heatindex_f': 80.2,
#     'dewpoint_c': 21.0,
#     'dewpoint_f': 69.8,
#     'will_it_rain': 1,
#     'chance_of_rain': '73',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 9.0,
#     'vis_miles': 5.0,
#     'gust_mph': 13.9,
#     'gust_kph': 22.3,
#     'uv': 6.0},
#    {'time_epoch': 1624287600,
#     'time': '2021-06-21 11:00',
#     'temp_c': 27.3,
#     'temp_f': 81.1,
#     'is_day': 1,
#     'condition': {'text': 'Patchy light rain with thunder',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#      'code': 1273},
#     'wind_mph': 12.1,
#     'wind_kph': 19.4,
#     'wind_degree': 220,
#     'wind_dir': 'SW',
#     'pressure_mb': 1003.0,
#     'pressure_in': 30.1,
#     'precip_mm': 0.3,
#     'precip_in': 0.01,
#     'humidity': 70,
#     'cloud': 78,
#     'feelslike_c': 29.7,
#     'feelslike_f': 85.5,
#     'windchill_c': 27.3,
#     'windchill_f': 81.1,
#     'heatindex_c': 29.7,
#     'heatindex_f': 85.5,
#     'dewpoint_c': 21.3,
#     'dewpoint_f': 70.3,
#     'will_it_rain': 1,
#     'chance_of_rain': '74',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 14.3,
#     'gust_kph': 23.0,
#     'uv': 6.0},
#    {'time_epoch': 1624291200,
#     'time': '2021-06-21 12:00',
#     'temp_c': 27.0,
#     'temp_f': 80.6,
#     'is_day': 1,
#     'condition': {'text': 'Patchy light rain with thunder',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#      'code': 1273},
#     'wind_mph': 12.3,
#     'wind_kph': 19.8,
#     'wind_degree': 223,
#     'wind_dir': 'SW',
#     'pressure_mb': 1003.0,
#     'pressure_in': 30.1,
#     'precip_mm': 0.9,
#     'precip_in': 0.04,
#     'humidity': 74,
#     'cloud': 78,
#     'feelslike_c': 29.6,
#     'feelslike_f': 85.3,
#     'windchill_c': 27.0,
#     'windchill_f': 80.6,
#     'heatindex_c': 29.6,
#     'heatindex_f': 85.3,
#     'dewpoint_c': 21.9,
#     'dewpoint_f': 71.4,
#     'will_it_rain': 1,
#     'chance_of_rain': '77',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 16.1,
#     'gust_kph': 25.9,
#     'uv': 6.0},
#    {'time_epoch': 1624294800,
#     'time': '2021-06-21 13:00',
#     'temp_c': 26.6,
#     'temp_f': 79.9,
#     'is_day': 1,
#     'condition': {'text': 'Patchy light rain with thunder',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#      'code': 1273},
#     'wind_mph': 12.8,
#     'wind_kph': 20.5,
#     'wind_degree': 226,
#     'wind_dir': 'SW',
#     'pressure_mb': 1003.0,
#     'pressure_in': 30.1,
#     'precip_mm': 1.6,
#     'precip_in': 0.06,
#     'humidity': 79,
#     'cloud': 78,
#     'feelslike_c': 29.5,
#     'feelslike_f': 85.1,
#     'windchill_c': 26.6,
#     'windchill_f': 79.9,
#     'heatindex_c': 29.5,
#     'heatindex_f': 85.1,
#     'dewpoint_c': 22.6,
#     'dewpoint_f': 72.7,
#     'will_it_rain': 1,
#     'chance_of_rain': '81',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 17.9,
#     'gust_kph': 28.8,
#     'uv': 6.0},
#    {'time_epoch': 1624298400,
#     'time': '2021-06-21 14:00',
#     'temp_c': 26.3,
#     'temp_f': 79.3,
#     'is_day': 1,
#     'condition': {'text': 'Patchy light rain with thunder',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#      'code': 1273},
#     'wind_mph': 13.0,
#     'wind_kph': 20.9,
#     'wind_degree': 230,
#     'wind_dir': 'SW',
#     'pressure_mb': 1003.0,
#     'pressure_in': 30.1,
#     'precip_mm': 2.2,
#     'precip_in': 0.09,
#     'humidity': 83,
#     'cloud': 78,
#     'feelslike_c': 29.4,
#     'feelslike_f': 84.9,
#     'windchill_c': 26.3,
#     'windchill_f': 79.3,
#     'heatindex_c': 29.4,
#     'heatindex_f': 84.9,
#     'dewpoint_c': 23.2,
#     'dewpoint_f': 73.8,
#     'will_it_rain': 1,
#     'chance_of_rain': '84',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 19.7,
#     'gust_kph': 31.7,
#     'uv': 6.0},
#    {'time_epoch': 1624302000,
#     'time': '2021-06-21 15:00',
#     'temp_c': 25.2,
#     'temp_f': 77.4,
#     'is_day': 1,
#     'condition': {'text': 'Moderate or heavy rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/356.png',
#      'code': 1243},
#     'wind_mph': 12.5,
#     'wind_kph': 20.2,
#     'wind_degree': 243,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1003.0,
#     'pressure_in': 30.1,
#     'precip_mm': 2.6,
#     'precip_in': 0.1,
#     'humidity': 87,
#     'cloud': 83,
#     'feelslike_c': 28.1,
#     'feelslike_f': 82.6,
#     'windchill_c': 25.2,
#     'windchill_f': 77.4,
#     'heatindex_c': 28.1,
#     'heatindex_f': 82.6,
#     'dewpoint_c': 22.8,
#     'dewpoint_f': 73.0,
#     'will_it_rain': 1,
#     'chance_of_rain': '86',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 9.0,
#     'vis_miles': 5.0,
#     'gust_mph': 19.7,
#     'gust_kph': 31.7,
#     'uv': 6.0},
#    {'time_epoch': 1624305600,
#     'time': '2021-06-21 16:00',
#     'temp_c': 24.1,
#     'temp_f': 75.4,
#     'is_day': 1,
#     'condition': {'text': 'Patchy light rain with thunder',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#      'code': 1273},
#     'wind_mph': 12.1,
#     'wind_kph': 19.4,
#     'wind_degree': 256,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1003.0,
#     'pressure_in': 30.1,
#     'precip_mm': 3.1,
#     'precip_in': 0.12,
#     'humidity': 91,
#     'cloud': 89,
#     'feelslike_c': 26.7,
#     'feelslike_f': 80.1,
#     'windchill_c': 24.1,
#     'windchill_f': 75.4,
#     'heatindex_c': 26.7,
#     'heatindex_f': 80.1,
#     'dewpoint_c': 22.4,
#     'dewpoint_f': 72.3,
#     'will_it_rain': 1,
#     'chance_of_rain': '87',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 8.0,
#     'vis_miles': 4.0,
#     'gust_mph': 19.7,
#     'gust_kph': 31.7,
#     'uv': 5.0},
#    {'time_epoch': 1624309200,
#     'time': '2021-06-21 17:00',
#     'temp_c': 23.0,
#     'temp_f': 73.4,
#     'is_day': 1,
#     'condition': {'text': 'Moderate or heavy rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/356.png',
#      'code': 1243},
#     'wind_mph': 11.6,
#     'wind_kph': 18.7,
#     'wind_degree': 269,
#     'wind_dir': 'W',
#     'pressure_mb': 1004.0,
#     'pressure_in': 30.1,
#     'precip_mm': 3.5,
#     'precip_in': 0.14,
#     'humidity': 94,
#     'cloud': 94,
#     'feelslike_c': 25.4,
#     'feelslike_f': 77.7,
#     'windchill_c': 23.0,
#     'windchill_f': 73.4,
#     'heatindex_c': 25.4,
#     'heatindex_f': 77.7,
#     'dewpoint_c': 22.0,
#     'dewpoint_f': 71.6,
#     'will_it_rain': 1,
#     'chance_of_rain': '89',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 7.0,
#     'vis_miles': 4.0,
#     'gust_mph': 19.7,
#     'gust_kph': 31.7,
#     'uv': 5.0},
#    {'time_epoch': 1624312800,
#     'time': '2021-06-21 18:00',
#     'temp_c': 21.7,
#     'temp_f': 71.1,
#     'is_day': 1,
#     'condition': {'text': 'Light rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#      'code': 1240},
#     'wind_mph': 10.3,
#     'wind_kph': 16.6,
#     'wind_degree': 285,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1005.0,
#     'pressure_in': 30.1,
#     'precip_mm': 3.1,
#     'precip_in': 0.12,
#     'humidity': 94,
#     'cloud': 82,
#     'feelslike_c': 21.7,
#     'feelslike_f': 71.1,
#     'windchill_c': 21.7,
#     'windchill_f': 71.1,
#     'heatindex_c': 24.3,
#     'heatindex_f': 75.7,
#     'dewpoint_c': 20.2,
#     'dewpoint_f': 68.4,
#     'will_it_rain': 1,
#     'chance_of_rain': '85',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 8.0,
#     'vis_miles': 4.0,
#     'gust_mph': 17.2,
#     'gust_kph': 27.7,
#     'uv': 5.0},
#    {'time_epoch': 1624316400,
#     'time': '2021-06-21 19:00',
#     'temp_c': 20.3,
#     'temp_f': 68.5,
#     'is_day': 1,
#     'condition': {'text': 'Moderate or heavy rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/356.png',
#      'code': 1243},
#     'wind_mph': 8.7,
#     'wind_kph': 14.0,
#     'wind_degree': 301,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1006.0,
#     'pressure_in': 30.2,
#     'precip_mm': 2.7,
#     'precip_in': 0.11,
#     'humidity': 94,
#     'cloud': 70,
#     'feelslike_c': 20.3,
#     'feelslike_f': 68.5,
#     'windchill_c': 20.3,
#     'windchill_f': 68.5,
#     'heatindex_c': 23.1,
#     'heatindex_f': 73.6,
#     'dewpoint_c': 18.5,
#     'dewpoint_f': 65.3,
#     'will_it_rain': 1,
#     'chance_of_rain': '82',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 9.0,
#     'vis_miles': 5.0,
#     'gust_mph': 15.0,
#     'gust_kph': 24.1,
#     'uv': 5.0},
#    {'time_epoch': 1624320000,
#     'time': '2021-06-21 20:00',
#     'temp_c': 19.0,
#     'temp_f': 66.2,
#     'is_day': 1,
#     'condition': {'text': 'Light rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#      'code': 1240},
#     'wind_mph': 7.4,
#     'wind_kph': 11.9,
#     'wind_degree': 316,
#     'wind_dir': 'NW',
#     'pressure_mb': 1007.0,
#     'pressure_in': 30.2,
#     'precip_mm': 2.3,
#     'precip_in': 0.09,
#     'humidity': 93,
#     'cloud': 58,
#     'feelslike_c': 19.0,
#     'feelslike_f': 66.2,
#     'windchill_c': 19.0,
#     'windchill_f': 66.2,
#     'heatindex_c': 22.0,
#     'heatindex_f': 71.6,
#     'dewpoint_c': 16.7,
#     'dewpoint_f': 62.1,
#     'will_it_rain': 1,
#     'chance_of_rain': '79',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.5,
#     'gust_kph': 20.2,
#     'uv': 4.0},
#    {'time_epoch': 1624323600,
#     'time': '2021-06-21 21:00',
#     'temp_c': 18.2,
#     'temp_f': 64.8,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 6.5,
#     'wind_kph': 10.4,
#     'wind_degree': 299,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1008.0,
#     'pressure_in': 30.2,
#     'precip_mm': 1.5,
#     'precip_in': 0.06,
#     'humidity': 90,
#     'cloud': 59,
#     'feelslike_c': 18.2,
#     'feelslike_f': 64.8,
#     'windchill_c': 18.2,
#     'windchill_f': 64.8,
#     'heatindex_c': 20.2,
#     'heatindex_f': 68.4,
#     'dewpoint_c': 15.8,
#     'dewpoint_f': 60.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '53',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 10.7,
#     'gust_kph': 17.3,
#     'uv': 1.0},
#    {'time_epoch': 1624327200,
#     'time': '2021-06-21 22:00',
#     'temp_c': 17.4,
#     'temp_f': 63.3,
#     'is_day': 0,
#     'condition': {'text': 'Light rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#      'code': 1240},
#     'wind_mph': 5.6,
#     'wind_kph': 9.0,
#     'wind_degree': 282,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1008.0,
#     'pressure_in': 30.2,
#     'precip_mm': 0.8,
#     'precip_in': 0.03,
#     'humidity': 87,
#     'cloud': 61,
#     'feelslike_c': 17.4,
#     'feelslike_f': 63.3,
#     'windchill_c': 17.4,
#     'windchill_f': 63.3,
#     'heatindex_c': 18.4,
#     'heatindex_f': 65.1,
#     'dewpoint_c': 14.9,
#     'dewpoint_f': 58.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '26',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 9.2,
#     'gust_kph': 14.8,
#     'uv': 1.0},
#    {'time_epoch': 1624330800,
#     'time': '2021-06-21 23:00',
#     'temp_c': 16.6,
#     'temp_f': 61.9,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 4.7,
#     'wind_kph': 7.6,
#     'wind_degree': 265,
#     'wind_dir': 'W',
#     'pressure_mb': 1009.0,
#     'pressure_in': 30.3,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 85,
#     'cloud': 62,
#     'feelslike_c': 16.6,
#     'feelslike_f': 61.9,
#     'windchill_c': 16.6,
#     'windchill_f': 61.9,
#     'heatindex_c': 16.6,
#     'heatindex_f': 61.9,
#     'dewpoint_c': 14.0,
#     'dewpoint_f': 57.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.4,
#     'gust_kph': 11.9,
#     'uv': 1.0}]},
#  {'date': '2021-06-22',
#   'date_epoch': 1624320000,
#   'day': {'maxtemp_c': 19.1,
#    'maxtemp_f': 66.4,
#    'mintemp_c': 11.0,
#    'mintemp_f': 51.8,
#    'avgtemp_c': 14.8,
#    'avgtemp_f': 58.7,
#    'maxwind_mph': 8.5,
#    'maxwind_kph': 13.7,
#    'totalprecip_mm': 3.9,
#    'totalprecip_in': 0.15,
#    'avgvis_km': 8.8,
#    'avgvis_miles': 5.0,
#    'avghumidity': 74.0,
#    'daily_will_it_rain': 1,
#    'daily_chance_of_rain': '81',
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': '0',
#    'condition': {'text': 'Patchy rain possible',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#     'code': 1063},
#    'uv': 7.0},
#   'astro': {'sunrise': '05:50 AM',
#    'sunset': '08:54 PM',
#    'moonrise': '06:49 PM',
#    'moonset': '03:51 AM',
#    'moon_phase': 'Full Moon',
#    'moon_illumination': '90'},
#   'hour': [{'time_epoch': 1624334400,
#     'time': '2021-06-22 00:00',
#     'temp_c': 16.0,
#     'temp_f': 60.8,
#     'is_day': 0,
#     'condition': {'text': 'Light drizzle',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/266.png',
#      'code': 1153},
#     'wind_mph': 5.4,
#     'wind_kph': 8.6,
#     'wind_degree': 281,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1009.0,
#     'pressure_in': 30.3,
#     'precip_mm': 0.1,
#     'precip_in': 0.0,
#     'humidity': 88,
#     'cloud': 75,
#     'feelslike_c': 15.8,
#     'feelslike_f': 60.4,
#     'windchill_c': 15.8,
#     'windchill_f': 60.4,
#     'heatindex_c': 16.0,
#     'heatindex_f': 60.8,
#     'dewpoint_c': 14.1,
#     'dewpoint_f': 57.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '29',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 7.3,
#     'vis_miles': 4.0,
#     'gust_mph': 8.1,
#     'gust_kph': 13.0,
#     'uv': 1.0},
#    {'time_epoch': 1624338000,
#     'time': '2021-06-22 01:00',
#     'temp_c': 15.5,
#     'temp_f': 59.9,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 6.3,
#     'wind_kph': 10.1,
#     'wind_degree': 298,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1010.0,
#     'pressure_in': 30.3,
#     'precip_mm': 0.1,
#     'precip_in': 0.0,
#     'humidity': 92,
#     'cloud': 87,
#     'feelslike_c': 15.1,
#     'feelslike_f': 59.2,
#     'windchill_c': 15.1,
#     'windchill_f': 59.2,
#     'heatindex_c': 15.5,
#     'heatindex_f': 59.9,
#     'dewpoint_c': 14.2,
#     'dewpoint_f': 57.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '57',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 4.7,
#     'vis_miles': 2.0,
#     'gust_mph': 8.7,
#     'gust_kph': 14.0,
#     'uv': 1.0},
#    {'time_epoch': 1624341600,
#     'time': '2021-06-22 02:00',
#     'temp_c': 14.9,
#     'temp_f': 58.8,
#     'is_day': 0,
#     'condition': {'text': 'Light drizzle',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/266.png',
#      'code': 1153},
#     'wind_mph': 6.9,
#     'wind_kph': 11.2,
#     'wind_degree': 314,
#     'wind_dir': 'NW',
#     'pressure_mb': 1010.0,
#     'pressure_in': 30.3,
#     'precip_mm': 0.2,
#     'precip_in': 0.01,
#     'humidity': 96,
#     'cloud': 100,
#     'feelslike_c': 14.3,
#     'feelslike_f': 57.7,
#     'windchill_c': 14.3,
#     'windchill_f': 57.7,
#     'heatindex_c': 14.9,
#     'heatindex_f': 58.8,
#     'dewpoint_c': 14.3,
#     'dewpoint_f': 57.7,
#     'will_it_rain': 1,
#     'chance_of_rain': '86',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 2.0,
#     'vis_miles': 1.0,
#     'gust_mph': 9.4,
#     'gust_kph': 15.1,
#     'uv': 1.0},
#    {'time_epoch': 1624345200,
#     'time': '2021-06-22 03:00',
#     'temp_c': 14.2,
#     'temp_f': 57.6,
#     'is_day': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#      'code': 1063},
#     'wind_mph': 6.7,
#     'wind_kph': 10.8,
#     'wind_degree': 317,
#     'wind_dir': 'NW',
#     'pressure_mb': 1011.0,
#     'pressure_in': 30.3,
#     'precip_mm': 0.2,
#     'precip_in': 0.01,
#     'humidity': 95,
#     'cloud': 100,
#     'feelslike_c': 13.5,
#     'feelslike_f': 56.3,
#     'windchill_c': 13.5,
#     'windchill_f': 56.3,
#     'heatindex_c': 14.2,
#     'heatindex_f': 57.6,
#     'dewpoint_c': 13.3,
#     'dewpoint_f': 55.9,
#     'will_it_rain': 1,
#     'chance_of_rain': '77',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 4.7,
# ...
#     'feelslike_f': 53.2,
#     'windchill_c': 11.8,
#     'windchill_f': 53.2,
#     'heatindex_c': 12.7,
#     'heatindex_f': 54.9,
#     'dewpoint_c': 11.4,
#     'dewpoint_f': 52.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '61',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.3,
#     'gust_kph': 13.3,
#     'uv': 1.0},
#    {'time_epoch': 1624356000,
#     'time': '2021-06-22 06:00',
#     'temp_c': 12.8,
#     'temp_f': 55.0,
#     'is_day': 1,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#      'code': 1063},
#     'wind_mph': 6.3,
#     'wind_kph': 10.1,
#     'wind_degree': 324,
#     'wind_dir': 'NW',
#     'pressure_mb': 1012.0,
#     'pressure_in': 30.4,
#     'precip_mm': 0.1,
#     'precip_in': 0.0,
#     'humidity': 88,
#     'cloud': 85,
#     'feelslike_c': 12.0,
#     'feelslike_f': 53.6,
#     'windchill_c': 12.0,
#     'windchill_f': 53.6,
#     'heatindex_c': 12.8,
#     'heatindex_f': 55.0,
#     'dewpoint_c': 10.8,
#     'dewpoint_f': 51.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '69',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.8,
#     'gust_kph': 12.6,
#     'uv': 3.0},
#    {'time_epoch': 1624359600,
#     'time': '2021-06-22 07:00',
#     'temp_c': 12.9,
#     'temp_f': 55.2,
#     'is_day': 1,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#      'code': 1063},
#     'wind_mph': 6.0,
#     'wind_kph': 9.7,
#     'wind_degree': 325,
#     'wind_dir': 'NW',
#     'pressure_mb': 1013.0,
#     'pressure_in': 30.4,
#     'precip_mm': 0.1,
#     'precip_in': 0.0,
#     'humidity': 84,
#     'cloud': 70,
#     'feelslike_c': 12.1,
#     'feelslike_f': 53.8,
#     'windchill_c': 12.1,
#     'windchill_f': 53.8,
#     'heatindex_c': 12.9,
#     'heatindex_f': 55.2,
#     'dewpoint_c': 10.2,
#     'dewpoint_f': 50.4,
#     'will_it_rain': 1,
#     'chance_of_rain': '78',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.4,
#     'gust_kph': 11.9,
#     'uv': 3.0},
#    {'time_epoch': 1624363200,
#     'time': '2021-06-22 08:00',
#     'temp_c': 13.0,
#     'temp_f': 55.4,
#     'is_day': 1,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#      'code': 1063},
#     'wind_mph': 6.0,
#     'wind_kph': 9.7,
#     'wind_degree': 325,
#     'wind_dir': 'NW',
#     'pressure_mb': 1014.0,
#     'pressure_in': 30.4,
#     'precip_mm': 0.1,
#     'precip_in': 0.0,
#     'humidity': 80,
#     'cloud': 55,
#     'feelslike_c': 12.3,
#     'feelslike_f': 54.1,
#     'windchill_c': 12.3,
#     'windchill_f': 54.1,
#     'heatindex_c': 13.0,
#     'heatindex_f': 55.4,
#     'dewpoint_c': 9.6,
#     'dewpoint_f': 49.3,
#     'will_it_rain': 1,
#     'chance_of_rain': '86',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.9,
#     'gust_kph': 11.2,
#     'uv': 3.0},
#    {'time_epoch': 1624366800,
#     'time': '2021-06-22 09:00',
#     'temp_c': 13.6,
#     'temp_f': 56.5,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 6.0,
#     'wind_kph': 9.7,
#     'wind_degree': 323,
#     'wind_dir': 'NW',
#     'pressure_mb': 1014.0,
#     'pressure_in': 30.4,
#     'precip_mm': 0.1,
#     'precip_in': 0.0,
#     'humidity': 75,
#     'cloud': 50,
#     'feelslike_c': 12.9,
#     'feelslike_f': 55.2,
#     'windchill_c': 12.9,
#     'windchill_f': 55.2,
#     'heatindex_c': 13.6,
#     'heatindex_f': 56.5,
#     'dewpoint_c': 9.2,
#     'dewpoint_f': 48.6,
#     'will_it_rain': 0,
#     'chance_of_rain': '57',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.9,
#     'gust_kph': 11.2,
#     'uv': 4.0},
#    {'time_epoch': 1624370400,
#     'time': '2021-06-22 10:00',
#     'temp_c': 14.1,
#     'temp_f': 57.4,
#     'is_day': 1,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#      'code': 1063},
#     'wind_mph': 6.3,
#     'wind_kph': 10.1,
#     'wind_degree': 320,
#     'wind_dir': 'NW',
#     'pressure_mb': 1015.0,
#     'pressure_in': 30.4,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 71,
#     'cloud': 45,
#     'feelslike_c': 13.6,
#     'feelslike_f': 56.5,
#     'windchill_c': 13.6,
#     'windchill_f': 56.5,
#     'heatindex_c': 14.1,
#     'heatindex_f': 57.4,
#     'dewpoint_c': 8.8,
#     'dewpoint_f': 47.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '29',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.2,
#     'gust_kph': 11.5,
#     'uv': 3.0},
#    {'time_epoch': 1624374000,
#     'time': '2021-06-22 11:00',
#     'temp_c': 14.7,
#     'temp_f': 58.5,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 6.3,
#     'wind_kph': 10.1,
#     'wind_degree': 317,
#     'wind_dir': 'NW',
#     'pressure_mb': 1015.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 66,
#     'cloud': 40,
#     'feelslike_c': 14.2,
#     'feelslike_f': 57.6,
#     'windchill_c': 14.2,
#     'windchill_f': 57.6,
#     'heatindex_c': 14.7,
#     'heatindex_f': 58.5,
#     'dewpoint_c': 8.4,
#     'dewpoint_f': 47.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.2,
#     'gust_kph': 11.5,
#     'uv': 4.0},
#    {'time_epoch': 1624377600,
#     'time': '2021-06-22 12:00',
#     'temp_c': 16.2,
#     'temp_f': 61.2,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 6.5,
#     'wind_kph': 10.4,
#     'wind_degree': 318,
#     'wind_dir': 'NW',
#     'pressure_mb': 1015.0,
#     'pressure_in': 30.4,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 59,
#     'cloud': 35,
#     'feelslike_c': 15.9,
#     'feelslike_f': 60.6,
#     'windchill_c': 15.9,
#     'windchill_f': 60.6,
#     'heatindex_c': 16.2,
#     'heatindex_f': 61.2,
#     'dewpoint_c': 7.7,
#     'dewpoint_f': 45.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.6,
#     'gust_kph': 12.2,
#     'uv': 5.0},
#    {'time_epoch': 1624381200,
#     'time': '2021-06-22 13:00',
#     'temp_c': 17.7,
#     'temp_f': 63.9,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 6.9,
#     'wind_kph': 11.2,
#     'wind_degree': 319,
#     'wind_dir': 'NW',
#     'pressure_mb': 1015.0,
#     'pressure_in': 30.4,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 51,
#     'cloud': 29,
#     'feelslike_c': 17.5,
#     'feelslike_f': 63.5,
#     'windchill_c': 17.5,
#     'windchill_f': 63.5,
#     'heatindex_c': 17.7,
#     'heatindex_f': 63.9,
#     'dewpoint_c': 7.1,
#     'dewpoint_f': 44.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.8,
#     'gust_kph': 12.6,
#     'uv': 5.0},
#    {'time_epoch': 1624384800,
#     'time': '2021-06-22 14:00',
#     'temp_c': 19.2,
#     'temp_f': 66.6,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 7.2,
#     'wind_kph': 11.5,
#     'wind_degree': 321,
#     'wind_dir': 'NW',
#     'pressure_mb': 1015.0,
#     'pressure_in': 30.4,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 43,
#     'cloud': 24,
#     'feelslike_c': 19.2,
#     'feelslike_f': 66.6,
#     'windchill_c': 19.2,
#     'windchill_f': 66.6,
#     'heatindex_c': 19.2,
#     'heatindex_f': 66.6,
#     'dewpoint_c': 6.4,
#     'dewpoint_f': 43.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.3,
#     'gust_kph': 13.3,
#     'uv': 5.0},
#    {'time_epoch': 1624388400,
#     'time': '2021-06-22 15:00',
#     'temp_c': 19.4,
#     'temp_f': 66.9,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 7.6,
#     'wind_kph': 12.2,
#     'wind_degree': 323,
#     'wind_dir': 'NW',
#     'pressure_mb': 1015.0,
#     'pressure_in': 30.4,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 43,
#     'cloud': 25,
#     'feelslike_c': 19.4,
#     'feelslike_f': 66.9,
#     'windchill_c': 19.4,
#     'windchill_f': 66.9,
#     'heatindex_c': 19.4,
#     'heatindex_f': 66.9,
#     'dewpoint_c': 6.4,
#     'dewpoint_f': 43.5,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.7,
#     'gust_kph': 14.0,
#     'uv': 5.0},
#    {'time_epoch': 1624392000,
#     'time': '2021-06-22 16:00',
#     'temp_c': 19.7,
#     'temp_f': 67.5,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 8.1,
#     'wind_kph': 13.0,
#     'wind_degree': 326,
#     'wind_dir': 'NNW',
#     'pressure_mb': 1014.0,
#     'pressure_in': 30.4,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 42,
#     'cloud': 25,
#     'feelslike_c': 19.7,
#     'feelslike_f': 67.5,
#     'windchill_c': 19.7,
#     'windchill_f': 67.5,
#     'heatindex_c': 19.7,
#     'heatindex_f': 67.5,
#     'dewpoint_c': 6.3,
#     'dewpoint_f': 43.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 9.4,
#     'gust_kph': 15.1,
#     'uv': 5.0},
#    {'time_epoch': 1624395600,
#     'time': '2021-06-22 17:00',
#     'temp_c': 19.9,
#     'temp_f': 67.8,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 8.5,
#     'wind_kph': 13.7,
#     'wind_degree': 329,
#     'wind_dir': 'NNW',
#     'pressure_mb': 1014.0,
#     'pressure_in': 30.4,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 41,
#     'cloud': 26,
#     'feelslike_c': 19.9,
#     'feelslike_f': 67.8,
#     'windchill_c': 19.9,
#     'windchill_f': 67.8,
#     'heatindex_c': 19.9,
#     'heatindex_f': 67.8,
#     'dewpoint_c': 6.3,
#     'dewpoint_f': 43.3,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 9.8,
#     'gust_kph': 15.8,
#     'uv': 5.0},
#    {'time_epoch': 1624399200,
#     'time': '2021-06-22 18:00',
#     'temp_c': 18.3,
#     'temp_f': 64.9,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 8.3,
#     'wind_kph': 13.3,
#     'wind_degree': 337,
#     'wind_dir': 'NNW',
#     'pressure_mb': 1015.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 47,
#     'cloud': 21,
#     'feelslike_c': 18.3,
#     'feelslike_f': 64.9,
#     'windchill_c': 18.3,
#     'windchill_f': 64.9,
#     'heatindex_c': 18.3,
#     'heatindex_f': 64.9,
#     'dewpoint_c': 6.6,
#     'dewpoint_f': 43.9,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 10.5,
#     'gust_kph': 16.9,
#     'uv': 5.0},
#    {'time_epoch': 1624402800,
#     'time': '2021-06-22 19:00',
#     'temp_c': 16.8,
#     'temp_f': 62.2,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 8.3,
#     'wind_kph': 13.3,
#     'wind_degree': 344,
#     'wind_dir': 'NNW',
#     'pressure_mb': 1016.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 53,
#     'cloud': 16,
#     'feelslike_c': 16.8,
#     'feelslike_f': 62.2,
#     'windchill_c': 16.8,
#     'windchill_f': 62.2,
#     'heatindex_c': 16.8,
#     'heatindex_f': 62.2,
#     'dewpoint_c': 6.8,
#     'dewpoint_f': 44.2,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.2,
#     'gust_kph': 18.0,
#     'uv': 5.0},
#    {'time_epoch': 1624406400,
#     'time': '2021-06-22 20:00',
#     'temp_c': 15.2,
#     'temp_f': 59.4,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 8.1,
#     'wind_kph': 13.0,
#     'wind_degree': 352,
#     'wind_dir': 'N',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 58,
#     'cloud': 11,
#     'feelslike_c': 15.2,
#     'feelslike_f': 59.4,
#     'windchill_c': 15.2,
#     'windchill_f': 59.4,
#     'heatindex_c': 15.2,
#     'heatindex_f': 59.4,
#     'dewpoint_c': 7.1,
#     'dewpoint_f': 44.8,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.9,
#     'gust_kph': 19.1,
#     'uv': 5.0},
#    {'time_epoch': 1624410000,
#     'time': '2021-06-22 21:00',
#     'temp_c': 13.8,
#     'temp_f': 56.8,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 6.5,
#     'wind_kph': 10.4,
#     'wind_degree': 235,
#     'wind_dir': 'SW',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 63,
#     'cloud': 8,
#     'feelslike_c': 13.8,
#     'feelslike_f': 56.8,
#     'windchill_c': 13.8,
#     'windchill_f': 56.8,
#     'heatindex_c': 13.8,
#     'heatindex_f': 56.8,
#     'dewpoint_c': 6.9,
#     'dewpoint_f': 44.4,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 10.1,
#     'gust_kph': 16.2,
#     'uv': 1.0},
#    {'time_epoch': 1624413600,
#     'time': '2021-06-22 22:00',
#     'temp_c': 12.5,
#     'temp_f': 54.5,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 4.9,
#     'wind_kph': 7.9,
#     'wind_degree': 118,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 68,
#     'cloud': 6,
#     'feelslike_c': 12.3,
#     'feelslike_f': 54.1,
#     'windchill_c': 12.3,
#     'windchill_f': 54.1,
#     'heatindex_c': 12.5,
#     'heatindex_f': 54.5,
#     'dewpoint_c': 6.7,
#     'dewpoint_f': 44.1,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.5,
#     'gust_kph': 13.7,
#     'uv': 1.0},
#    {'time_epoch': 1624417200,
#     'time': '2021-06-22 23:00',
#     'temp_c': 11.1,
#     'temp_f': 52.0,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 1,
#     'wind_dir': 'N',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.6,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 73,
#     'cloud': 3,
#     'feelslike_c': 10.9,
#     'feelslike_f': 51.6,
#     'windchill_c': 10.9,
#     'windchill_f': 51.6,
#     'heatindex_c': 11.1,
#     'heatindex_f': 52.0,
#     'dewpoint_c': 6.5,
#     'dewpoint_f': 43.7,
#     'will_it_rain': 0,
#     'chance_of_rain': '0',
#     'will_it_snow': 0,
#     'chance_of_snow': '0',
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.7,
#     'gust_kph': 10.8,
#     'uv': 1.0}]}]

# %%
pittsburgh_forecast.json()['forecast']['forecastday'][0]
# Out:
# {'date': '2021-06-20',
#  'date_epoch': 1624147200,
#  'day': {'maxtemp_c': 29.7,
#   'maxtemp_f': 85.5,
#   'mintemp_c': 16.5,
#   'mintemp_f': 61.7,
#   'avgtemp_c': 23.5,
#   'avgtemp_f': 74.4,
#   'maxwind_mph': 9.2,
#   'maxwind_kph': 14.8,
#   'totalprecip_mm': 6.9,
#   'totalprecip_in': 0.27,
#   'avgvis_km': 7.8,
#   'avgvis_miles': 4.0,
#   'avghumidity': 83.0,
#   'daily_will_it_rain': 1,
#   'daily_chance_of_rain': '76',
#   'daily_will_it_snow': 0,
#   'daily_chance_of_snow': '0',
#   'condition': {'text': 'Moderate rain',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png',
#    'code': 1189},
#   'uv': 7.0},
#  'astro': {'sunrise': '05:50 AM',
#   'sunset': '08:54 PM',
#   'moonrise': '04:14 PM',
#   'moonset': '02:45 AM',
#   'moon_phase': 'Full Moon',
#   'moon_illumination': '76'},
#  'hour': [{'time_epoch': 1624161600,
#    'time': '2021-06-20 00:00',
#    'temp_c': 18.6,
#    'temp_f': 65.5,
#    'is_day': 0,
#    'condition': {'text': 'Fog',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png',
#     'code': 1135},
#    'wind_mph': 5.4,
#    'wind_kph': 8.6,
#    'wind_degree': 230,
#    'wind_dir': 'SW',
#    'pressure_mb': 1009.0,
#    'pressure_in': 30.3,
#    'precip_mm': 1.6,
#    'precip_in': 0.06,
#    'humidity': 99,
#    'cloud': 67,
#    'feelslike_c': 18.6,
#    'feelslike_f': 65.5,
#    'windchill_c': 18.6,
#    'windchill_f': 65.5,
#    'heatindex_c': 18.6,
#    'heatindex_f': 65.5,
#    'dewpoint_c': 18.4,
#    'dewpoint_f': 65.1,
#    'will_it_rain': 0,
#    'chance_of_rain': '41',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 6.7,
#    'vis_miles': 4.0,
#    'gust_mph': 10.1,
#    'gust_kph': 16.2,
#    'uv': 1.0},
#   {'time_epoch': 1624165200,
#    'time': '2021-06-20 01:00',
#    'temp_c': 18.2,
#    'temp_f': 64.8,
#    'is_day': 0,
#    'condition': {'text': 'Light rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#     'code': 1240},
#    'wind_mph': 4.9,
#    'wind_kph': 7.9,
#    'wind_degree': 225,
#    'wind_dir': 'SW',
#    'pressure_mb': 1009.0,
#    'pressure_in': 30.3,
#    'precip_mm': 0.8,
#    'precip_in': 0.03,
#    'humidity': 99,
#    'cloud': 84,
#    'feelslike_c': 18.2,
#    'feelslike_f': 64.8,
#    'windchill_c': 18.2,
#    'windchill_f': 64.8,
#    'heatindex_c': 18.2,
#    'heatindex_f': 64.8,
#    'dewpoint_c': 18.0,
#    'dewpoint_f': 64.4,
#    'will_it_rain': 0,
#    'chance_of_rain': '20',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 3.3,
#    'vis_miles': 2.0,
#    'gust_mph': 9.4,
#    'gust_kph': 15.1,
#    'uv': 1.0},
#   {'time_epoch': 1624168800,
#    'time': '2021-06-20 02:00',
#    'temp_c': 17.8,
#    'temp_f': 64.0,
#    'is_day': 0,
#    'condition': {'text': 'Fog',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png',
#     'code': 1135},
#    'wind_mph': 4.5,
#    'wind_kph': 7.2,
#    'wind_degree': 220,
#    'wind_dir': 'SW',
#    'pressure_mb': 1009.0,
#    'pressure_in': 30.3,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 99,
#    'cloud': 100,
#    'feelslike_c': 17.8,
#    'feelslike_f': 64.0,
#    'windchill_c': 17.8,
#    'windchill_f': 64.0,
#    'heatindex_c': 17.8,
#    'heatindex_f': 64.0,
#    'dewpoint_c': 17.7,
#    'dewpoint_f': 63.9,
#    'will_it_rain': 0,
#    'chance_of_rain': '0',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 0.0,
#    'vis_miles': 0.0,
#    'gust_mph': 8.9,
#    'gust_kph': 14.4,
#    'uv': 1.0},
#   {'time_epoch': 1624172400,
#    'time': '2021-06-20 03:00',
#    'temp_c': 17.4,
#    'temp_f': 63.3,
#    'is_day': 0,
#    'condition': {'text': 'Light rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#     'code': 1240},
#    'wind_mph': 4.3,
#    'wind_kph': 6.8,
#    'wind_degree': 213,
#    'wind_dir': 'SSW',
#    'pressure_mb': 1009.0,
#    'pressure_in': 30.3,
#    'precip_mm': 0.6,
#    'precip_in': 0.02,
#    'humidity': 99,
#    'cloud': 86,
#    'feelslike_c': 17.4,
#    'feelslike_f': 63.3,
#    'windchill_c': 17.4,
#    'windchill_f': 63.3,
#    'heatindex_c': 17.4,
#    'heatindex_f': 63.3,
#    'dewpoint_c': 17.3,
#    'dewpoint_f': 63.1,
#    'will_it_rain': 0,
#    'chance_of_rain': '19',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 3.3,
#    'vis_miles': 2.0,
#    'gust_mph': 8.5,
#    'gust_kph': 13.7,
#    'uv': 1.0},
#   {'time_epoch': 1624176000,
#    'time': '2021-06-20 04:00',
#    'temp_c': 16.9,
#    'temp_f': 62.4,
#    'is_day': 0,
#    'condition': {'text': 'Fog',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png',
#     'code': 1135},
#    'wind_mph': 3.8,
#    'wind_kph': 6.1,
#    'wind_degree': 207,
#    'wind_dir': 'SSW',
#    'pressure_mb': 1010.0,
#    'pressure_in': 30.3,
#    'precip_mm': 1.2,
#    'precip_in': 0.05,
#    'humidity': 99,
#    'cloud': 72,
#    'feelslike_c': 16.9,
#    'feelslike_f': 62.4,
#    'windchill_c': 16.9,
#    'windchill_f': 62.4,
#    'heatindex_c': 16.9,
#    'heatindex_f': 62.4,
#    'dewpoint_c': 16.8,
#    'dewpoint_f': 62.2,
#    'will_it_rain': 0,
#    'chance_of_rain': '39',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 6.7,
#    'vis_miles': 4.0,
#    'gust_mph': 7.8,
#    'gust_kph': 12.6,
#    'uv': 1.0},
#   {'time_epoch': 1624179600,
#    'time': '2021-06-20 05:00',
#    'temp_c': 16.5,
#    'temp_f': 61.7,
#    'is_day': 0,
#    'condition': {'text': 'Light rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#     'code': 1240},
#    'wind_mph': 3.6,
#    'wind_kph': 5.8,
#    'wind_degree': 200,
#    'wind_dir': 'SSW',
#    'pressure_mb': 1010.0,
#    'pressure_in': 30.3,
#    'precip_mm': 1.8,
#    'precip_in': 0.07,
#    'humidity': 99,
#    'cloud': 58,
#    'feelslike_c': 16.5,
#    'feelslike_f': 61.7,
#    'windchill_c': 16.5,
#    'windchill_f': 61.7,
#    'heatindex_c': 16.5,
#    'heatindex_f': 61.7,
#    'dewpoint_c': 16.4,
#    'dewpoint_f': 61.5,
#    'will_it_rain': 0,
#    'chance_of_rain': '58',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 7.4,
#    'gust_kph': 11.9,
#    'uv': 1.0},
#   {'time_epoch': 1624183200,
#    'time': '2021-06-20 06:00',
#    'temp_c': 17.5,
#    'temp_f': 63.5,
#    'is_day': 1,
#    'condition': {'text': 'Moderate or heavy rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/356.png',
#     'code': 1243},
#    'wind_mph': 4.0,
#    'wind_kph': 6.5,
#    'wind_degree': 202,
#    'wind_dir': 'SSW',
#    'pressure_mb': 1010.0,
#    'pressure_in': 30.3,
#    'precip_mm': 2.4,
#    'precip_in': 0.09,
#    'humidity': 99,
#    'cloud': 63,
#    'feelslike_c': 17.5,
#    'feelslike_f': 63.5,
#    'windchill_c': 17.5,
#    'windchill_f': 63.5,
#    'heatindex_c': 17.5,
#    'heatindex_f': 63.5,
#    'dewpoint_c': 17.3,
#    'dewpoint_f': 63.1,
#    'will_it_rain': 0,
#    'chance_of_rain': '62',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 7.8,
#    'gust_kph': 12.6,
#    'uv': 4.0},
#   {'time_epoch': 1624186800,
#    'time': '2021-06-20 07:00',
#    'temp_c': 18.6,
#    'temp_f': 65.5,
#    'is_day': 1,
#    'condition': {'text': 'Light rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#     'code': 1240},
#    'wind_mph': 4.5,
#    'wind_kph': 7.2,
#    'wind_degree': 204,
#    'wind_dir': 'SSW',
#    'pressure_mb': 1011.0,
#    'pressure_in': 30.3,
#    'precip_mm': 3.0,
#    'precip_in': 0.12,
#    'humidity': 98,
#    'cloud': 69,
#    'feelslike_c': 18.6,
#    'feelslike_f': 65.5,
#    'windchill_c': 18.6,
#    'windchill_f': 65.5,
#    'heatindex_c': 18.6,
#    'heatindex_f': 65.5,
#    'dewpoint_c': 18.3,
#    'dewpoint_f': 64.9,
#    'will_it_rain': 0,
#    'chance_of_rain': '65',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 8.0,
#    'vis_miles': 4.0,
#    'gust_mph': 8.1,
#    'gust_kph': 13.0,
#    'uv': 4.0},
#   {'time_epoch': 1624190400,
#    'time': '2021-06-20 08:00',
#    'temp_c': 19.6,
#    'temp_f': 67.3,
#    'is_day': 1,
#    'condition': {'text': 'Moderate or heavy rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/356.png',
#     'code': 1243},
#    'wind_mph': 4.9,
#    'wind_kph': 7.9,
#    'wind_degree': 205,
#    'wind_dir': 'SSW',
#    'pressure_mb': 1011.0,
#    'pressure_in': 30.3,
#    'precip_mm': 3.6,
#    'precip_in': 0.14,
#    'humidity': 98,
#    'cloud': 74,
#    'feelslike_c': 19.6,
#    'feelslike_f': 67.3,
#    'windchill_c': 19.6,
#    'windchill_f': 67.3,
#    'heatindex_c': 19.6,
#    'heatindex_f': 67.3,
#    'dewpoint_c': 19.2,
#    'dewpoint_f': 66.6,
#    'will_it_rain': 0,
#    'chance_of_rain': '69',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 7.0,
#    'vis_miles': 4.0,
#    'gust_mph': 8.5,
#    'gust_kph': 13.7,
#    'uv': 4.0},
#   {'time_epoch': 1624194000,
#    'time': '2021-06-20 09:00',
#    'temp_c': 21.4,
#    'temp_f': 70.5,
#    'is_day': 1,
#    'condition': {'text': 'Light rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#     'code': 1240},
#    'wind_mph': 6.0,
#    'wind_kph': 9.7,
#    'wind_degree': 210,
#    'wind_dir': 'SSW',
#    'pressure_mb': 1011.0,
#    'pressure_in': 30.3,
#    'precip_mm': 2.8,
#    'precip_in': 0.11,
#    'humidity': 93,
#    'cloud': 76,
#    'feelslike_c': 21.4,
#    'feelslike_f': 70.5,
#    'windchill_c': 21.4,
#    'windchill_f': 70.5,
#    'heatindex_c': 22.1,
#    'heatindex_f': 71.8,
#    'dewpoint_c': 20.2,
#    'dewpoint_f': 68.4,
#    'will_it_rain': 0,
#    'chance_of_rain': '68',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 8.0,
#    'vis_miles': 4.0,
#    'gust_mph': 9.4,
#    'gust_kph': 15.1,
#    'uv': 5.0},
#   {'time_epoch': 1624197600,
#    'time': '2021-06-20 10:00',
#    'temp_c': 23.1,
#    'temp_f': 73.6,
#    'is_day': 1,
#    'condition': {'text': 'Moderate or heavy rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/356.png',
#     'code': 1243},
#    'wind_mph': 7.4,
#    'wind_kph': 11.9,
#    'wind_degree': 214,
#    'wind_dir': 'SW',
#    'pressure_mb': 1010.0,
#    'pressure_in': 30.3,
#    'precip_mm': 1.9,
#    'precip_in': 0.07,
#    'humidity': 89,
#    'cloud': 77,
#    'feelslike_c': 24.7,
#    'feelslike_f': 76.5,
#    'windchill_c': 23.1,
#    'windchill_f': 73.6,
#    'heatindex_c': 24.7,
#    'heatindex_f': 76.5,
#    'dewpoint_c': 21.1,
#    'dewpoint_f': 70.0,
#    'will_it_rain': 0,
#    'chance_of_rain': '66',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 10.5,
#    'gust_kph': 16.9,
#    'uv': 5.0},
#   {'time_epoch': 1624201200,
#    'time': '2021-06-20 11:00',
#    'temp_c': 24.9,
#    'temp_f': 76.8,
#    'is_day': 1,
#    'condition': {'text': 'Light rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#     'code': 1240},
#    'wind_mph': 8.5,
#    'wind_kph': 13.7,
#    'wind_degree': 218,
#    'wind_dir': 'SW',
#    'pressure_mb': 1010.0,
#    'pressure_in': 30.3,
#    'precip_mm': 1.1,
#    'precip_in': 0.04,
#    'humidity': 84,
#    'cloud': 79,
#    'feelslike_c': 27.2,
#    'feelslike_f': 81.0,
#    'windchill_c': 24.9,
#    'windchill_f': 76.8,
#    'heatindex_c': 27.2,
#    'heatindex_f': 81.0,
#    'dewpoint_c': 22.1,
#    'dewpoint_f': 71.8,
#    'will_it_rain': 0,
#    'chance_of_rain': '65',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 11.4,
#    'gust_kph': 18.4,
#    'uv': 5.0},
#   {'time_epoch': 1624204800,
#    'time': '2021-06-20 12:00',
#    'temp_c': 26.4,
#    'temp_f': 79.5,
#    'is_day': 1,
#    'condition': {'text': 'Light rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#     'code': 1240},
#    'wind_mph': 8.9,
#    'wind_kph': 14.4,
#    'wind_degree': 225,
#    'wind_dir': 'SW',
#    'pressure_mb': 1009.0,
#    'pressure_in': 30.3,
#    'precip_mm': 1.1,
#    'precip_in': 0.04,
#    'humidity': 75,
#    'cloud': 81,
#    'feelslike_c': 28.6,
#    'feelslike_f': 83.5,
#    'windchill_c': 26.4,
#    'windchill_f': 79.5,
#    'heatindex_c': 28.6,
#    'heatindex_f': 83.5,
#    'dewpoint_c': 21.3,
#    'dewpoint_f': 70.3,
#    'will_it_rain': 0,
#    'chance_of_rain': '67',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 11.9,
#    'gust_kph': 19.1,
#    'uv': 6.0},
#   {'time_epoch': 1624208400,
#    'time': '2021-06-20 13:00',
#    'temp_c': 27.8,
#    'temp_f': 82.0,
#    'is_day': 1,
#    'condition': {'text': 'Light rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#     'code': 1240},
#    'wind_mph': 9.2,
#    'wind_kph': 14.8,
#    'wind_degree': 231,
#    'wind_dir': 'SW',
#    'pressure_mb': 1009.0,
#    'pressure_in': 30.3,
#    'precip_mm': 1.1,
#    'precip_in': 0.04,
#    'humidity': 66,
#    'cloud': 83,
#    'feelslike_c': 29.9,
#    'feelslike_f': 85.8,
#    'windchill_c': 27.8,
#    'windchill_f': 82.0,
#    'heatindex_c': 29.9,
#    'heatindex_f': 85.8,
#    'dewpoint_c': 20.6,
#    'dewpoint_f': 69.1,
#    'will_it_rain': 0,
#    'chance_of_rain': '68',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 12.3,
#    'gust_kph': 19.8,
#    'uv': 6.0},
#   {'time_epoch': 1624212000,
#    'time': '2021-06-20 14:00',
#    'temp_c': 29.3,
#    'temp_f': 84.7,
#    'is_day': 1,
#    'condition': {'text': 'Light rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#     'code': 1240},
#    'wind_mph': 9.6,
#    'wind_kph': 15.5,
#    'wind_degree': 238,
#    'wind_dir': 'WSW',
#    'pressure_mb': 1008.0,
#    'pressure_in': 30.2,
#    'precip_mm': 1.1,
#    'precip_in': 0.04,
#    'humidity': 57,
#    'cloud': 85,
#    'feelslike_c': 31.3,
#    'feelslike_f': 88.3,
#    'windchill_c': 29.3,
#    'windchill_f': 84.7,
#    'heatindex_c': 31.3,
#    'heatindex_f': 88.3,
#    'dewpoint_c': 19.8,
#    'dewpoint_f': 67.6,
#    'will_it_rain': 0,
#    'chance_of_rain': '70',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 12.8,
#    'gust_kph': 20.5,
#    'uv': 6.0},
#   {'time_epoch': 1624215600,
#    'time': '2021-06-20 15:00',
#    'temp_c': 29.5,
#    'temp_f': 85.1,
#    'is_day': 1,
#    'condition': {'text': 'Patchy light rain with thunder',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#     'code': 1273},
#    'wind_mph': 8.3,
#    'wind_kph': 13.3,
#    'wind_degree': 246,
#    'wind_dir': 'WSW',
#    'pressure_mb': 1007.0,
#    'pressure_in': 30.2,
#    'precip_mm': 0.8,
#    'precip_in': 0.03,
#    'humidity': 57,
#    'cloud': 83,
#    'feelslike_c': 31.8,
#    'feelslike_f': 89.2,
#    'windchill_c': 29.5,
#    'windchill_f': 85.1,
#    'heatindex_c': 31.8,
#    'heatindex_f': 89.2,
#    'dewpoint_c': 20.2,
#    'dewpoint_f': 68.4,
#    'will_it_rain': 1,
#    'chance_of_rain': '74',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 10.7,
#    'gust_kph': 17.3,
#    'uv': 6.0},
#   {'time_epoch': 1624219200,
#    'time': '2021-06-20 16:00',
#    'temp_c': 29.8,
#    'temp_f': 85.6,
#    'is_day': 1,
#    'condition': {'text': 'Light rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#     'code': 1240},
#    'wind_mph': 6.9,
#    'wind_kph': 11.2,
#    'wind_degree': 255,
#    'wind_dir': 'WSW',
#    'pressure_mb': 1007.0,
#    'pressure_in': 30.2,
#    'precip_mm': 0.6,
#    'precip_in': 0.02,
#    'humidity': 58,
#    'cloud': 81,
#    'feelslike_c': 32.3,
#    'feelslike_f': 90.1,
#    'windchill_c': 29.8,
#    'windchill_f': 85.6,
#    'heatindex_c': 32.3,
#    'heatindex_f': 90.1,
#    'dewpoint_c': 20.5,
#    'dewpoint_f': 68.9,
#    'will_it_rain': 1,
#    'chance_of_rain': '78',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 8.7,
#    'gust_kph': 14.0,
#    'uv': 6.0},
#   {'time_epoch': 1624222800,
#    'time': '2021-06-20 17:00',
#    'temp_c': 30.0,
#    'temp_f': 86.0,
#    'is_day': 1,
#    'condition': {'text': 'Patchy light rain with thunder',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#     'code': 1273},
#    'wind_mph': 5.6,
#    'wind_kph': 9.0,
#    'wind_degree': 263,
#    'wind_dir': 'W',
#    'pressure_mb': 1006.0,
#    'pressure_in': 30.2,
#    'precip_mm': 0.3,
#    'precip_in': 0.01,
#    'humidity': 58,
#    'cloud': 79,
#    'feelslike_c': 32.8,
#    'feelslike_f': 91.0,
#    'windchill_c': 30.0,
#    'windchill_f': 86.0,
#    'heatindex_c': 32.8,
#    'heatindex_f': 91.0,
#    'dewpoint_c': 20.9,
#    'dewpoint_f': 69.6,
#    'will_it_rain': 1,
#    'chance_of_rain': '82',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 6.7,
#    'gust_kph': 10.8,
#    'uv': 7.0},
#   {'time_epoch': 1624226400,
#    'time': '2021-06-20 18:00',
#    'temp_c': 28.7,
#    'temp_f': 83.7,
#    'is_day': 1,
#    'condition': {'text': 'Patchy light rain with thunder',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#     'code': 1273},
#    'wind_mph': 4.3,
#    'wind_kph': 6.8,
#    'wind_degree': 271,
#    'wind_dir': 'W',
#    'pressure_mb': 1006.0,
#    'pressure_in': 30.2,
#    'precip_mm': 0.3,
#    'precip_in': 0.01,
#    'humidity': 68,
#    'cloud': 77,
#    'feelslike_c': 31.2,
#    'feelslike_f': 88.2,
#    'windchill_c': 28.7,
#    'windchill_f': 83.7,
#    'heatindex_c': 31.2,
#    'heatindex_f': 88.2,
#    'dewpoint_c': 21.3,
#    'dewpoint_f': 70.3,
#    'will_it_rain': 1,
#    'chance_of_rain': '79',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 5.8,
#    'gust_kph': 9.4,
#    'uv': 6.0},
#   {'time_epoch': 1624230000,
#    'time': '2021-06-20 19:00',
#    'temp_c': 27.3,
#    'temp_f': 81.1,
#    'is_day': 1,
#    'condition': {'text': 'Patchy light rain with thunder',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#     'code': 1273},
#    'wind_mph': 3.1,
#    'wind_kph': 5.0,
#    'wind_degree': 279,
#    'wind_dir': 'W',
#    'pressure_mb': 1006.0,
#    'pressure_in': 30.2,
#    'precip_mm': 0.4,
#    'precip_in': 0.02,
#    'humidity': 77,
#    'cloud': 74,
#    'feelslike_c': 29.6,
#    'feelslike_f': 85.3,
#    'windchill_c': 27.3,
#    'windchill_f': 81.1,
#    'heatindex_c': 29.6,
#    'heatindex_f': 85.3,
#    'dewpoint_c': 21.8,
#    'dewpoint_f': 71.2,
#    'will_it_rain': 1,
#    'chance_of_rain': '75',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 4.7,
#    'gust_kph': 7.6,
#    'uv': 6.0},
#   {'time_epoch': 1624233600,
#    'time': '2021-06-20 20:00',
#    'temp_c': 26.0,
#    'temp_f': 78.8,
#    'is_day': 1,
#    'condition': {'text': 'Patchy light rain with thunder',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#     'code': 1273},
#    'wind_mph': 1.8,
#    'wind_kph': 2.9,
#    'wind_degree': 286,
#    'wind_dir': 'WNW',
#    'pressure_mb': 1006.0,
#    'pressure_in': 30.2,
#    'precip_mm': 0.4,
#    'precip_in': 0.02,
#    'humidity': 87,
#    'cloud': 72,
#    'feelslike_c': 28.0,
#    'feelslike_f': 82.4,
#    'windchill_c': 26.0,
#    'windchill_f': 78.8,
#    'heatindex_c': 28.0,
#    'heatindex_f': 82.4,
#    'dewpoint_c': 22.2,
#    'dewpoint_f': 72.0,
#    'will_it_rain': 1,
#    'chance_of_rain': '72',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 3.8,
#    'gust_kph': 6.1,
#    'uv': 6.0},
#   {'time_epoch': 1624237200,
#    'time': '2021-06-20 21:00',
#    'temp_c': 24.5,
#    'temp_f': 76.1,
#    'is_day': 0,
#    'condition': {'text': 'Patchy rain possible',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#     'code': 1063},
#    'wind_mph': 2.2,
#    'wind_kph': 3.6,
#    'wind_degree': 253,
#    'wind_dir': 'WSW',
#    'pressure_mb': 1006.0,
#    'pressure_in': 30.2,
#    'precip_mm': 0.3,
#    'precip_in': 0.01,
#    'humidity': 89,
#    'cloud': 73,
#    'feelslike_c': 26.7,
#    'feelslike_f': 80.1,
#    'windchill_c': 24.5,
#    'windchill_f': 76.1,
#    'heatindex_c': 26.7,
#    'heatindex_f': 80.1,
#    'dewpoint_c': 21.6,
#    'dewpoint_f': 70.9,
#    'will_it_rain': 1,
#    'chance_of_rain': '73',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 9.7,
#    'vis_miles': 6.0,
#    'gust_mph': 4.9,
#    'gust_kph': 7.9,
#    'uv': 1.0},
#   {'time_epoch': 1624240800,
#    'time': '2021-06-20 22:00',
#    'temp_c': 22.9,
#    'temp_f': 73.2,
#    'is_day': 0,
#    'condition': {'text': 'Patchy light rain with thunder',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/386.png',
#     'code': 1273},
#    'wind_mph': 2.9,
#    'wind_kph': 4.7,
#    'wind_degree': 220,
#    'wind_dir': 'SW',
#    'pressure_mb': 1006.0,
#    'pressure_in': 30.2,
#    'precip_mm': 0.3,
#    'precip_in': 0.01,
#    'humidity': 92,
#    'cloud': 73,
#    'feelslike_c': 25.5,
#    'feelslike_f': 77.9,
#    'windchill_c': 22.9,
#    'windchill_f': 73.2,
#    'heatindex_c': 25.5,
#    'heatindex_f': 77.9,
#    'dewpoint_c': 21.0,
#    'dewpoint_f': 69.8,
#    'will_it_rain': 1,
#    'chance_of_rain': '75',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 9.3,
#    'vis_miles': 5.0,
#    'gust_mph': 5.8,
#    'gust_kph': 9.4,
#    'uv': 1.0},
#   {'time_epoch': 1624244400,
#    'time': '2021-06-20 23:00',
#    'temp_c': 21.4,
#    'temp_f': 70.5,
#    'is_day': 0,
#    'condition': {'text': 'Patchy rain possible',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#     'code': 1063},
#    'wind_mph': 3.4,
#    'wind_kph': 5.4,
#    'wind_degree': 187,
#    'wind_dir': 'S',
#    'pressure_mb': 1006.0,
#    'pressure_in': 30.2,
#    'precip_mm': 0.2,
#    'precip_in': 0.01,
#    'humidity': 94,
#    'cloud': 74,
#    'feelslike_c': 21.4,
#    'feelslike_f': 70.5,
#    'windchill_c': 21.4,
#    'windchill_f': 70.5,
#    'heatindex_c': 24.2,
#    'heatindex_f': 75.6,
#    'dewpoint_c': 20.4,
#    'dewpoint_f': 68.7,
#    'will_it_rain': 1,
#    'chance_of_rain': '76',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 6.9,
#    'gust_kph': 11.2,
#    'uv': 1.0}]}

# %%
pittsburgh_forecast.json()['forecast']['forecastday'][0]['day']["maxtemp_f"]
# Out:
# 85.5

# %%
print(f"The difference between the high and low temperatures in Pittsburgh today is" , (round((pittsburgh_forecast.json()['forecast']['forecastday'][0]['day']["maxtemp_f"])-(pittsburgh_forecast.json()['forecast']['forecastday'][0]['day']["mintemp_f"])) , "degrees."))
# Out:
# The difference between the high and low temperatures in Pittsburgh today is (24, 'degrees.')

# %% [markdown]
# ## 4.5) How can you avoid the "oh no I don't have the data any more because I made another request" problem in the future?
#
# What variable(s) do you have to rename, and what would you rename them?

# %% [markdown]
# I think you have to rename the url each time. It also helps to make the variable you're calling a different name based on the data you're looking for (e.g. "I'm looking for Pittsburgh's forecast data, so instead of using 'data' again I will use 'pittsburgh_forecast.'")

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
pittsburgh_daily = requests.get ("http://api.weatherapi.com/v1/forecast.json?key=a5a33e5547704451b06180649211906&q=Pittsburgh&days=7")
print(pittsburgh_daily.json())
# Out:
# {'location': {'name': 'Pittsburgh', 'region': 'Pennsylvania', 'country': 'United States of America', 'lat': 40.44, 'lon': -80.0, 'tz_id': 'America/New_York', 'localtime_epoch': 1624235453, 'localtime': '2021-06-20 20:30'}, 'current': {'last_updated_epoch': 1624234500, 'last_updated': '2021-06-20 20:15', 'temp_c': 28.9, 'temp_f': 84.0, 'is_day': 1, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'wind_mph': 10.5, 'wind_kph': 16.9, 'wind_degree': 200, 'wind_dir': 'SSW', 'pressure_mb': 1008.0, 'pressure_in': 30.2, 'precip_mm': 0.3, 'precip_in': 0.01, 'humidity': 61, 'cloud': 0, 'feelslike_c': 30.9, 'feelslike_f': 87.7, 'vis_km': 14.0, 'vis_miles': 8.0, 'uv': 7.0, 'gust_mph': 6.7, 'gust_kph': 10.8}, 'forecast': {'forecastday': [{'date': '2021-06-20', 'date_epoch': 1624147200, 'day': {'maxtemp_c': 30.0, 'maxtemp_f': 86.0, 'mintemp_c': 16.5, 'mintemp_f': 61.7, 'avgtemp_c': 23.2, 'avgtemp_f': 73.7, 'maxwind_mph': 9.6, 'maxwind_kph': 15.5, 'totalprecip_mm': 8.5, 'totalprecip_in': 0.33, 'avgvis_km': 8.3, 'avgvis_miles': 5.0, 'avghumidity': 85.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': '82', 'daily_will_it_snow': 0, 'daily_chance_of_snow': '0', 'condition': {'text': 'Moderate rain', 'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png', 'code': 1189}, 'uv': 9.0}, 'astro': {'sunrise': '05:50 AM', 'sunset': '08:54 PM', 'moonrise': '04:14 PM', 'moonset': '02:45 AM', 'moon_phase': 'Full Moon', 'moon_illumination': '76'}, 'hour': [{'time_epoch': 1624161600, 'time': '2021-06-20 00:00', 'temp_c': 18.6, 'temp_f': 65.5, 'is_day': 0, 'condition': {'text': 'Fog', 'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png', 'code': 1135}, 'wind_mph': 5.4, 'wind_kph': 8.6, 'wind_degree': 230, 'wind_dir': 'SW', 'pressure_mb': 1009.0, 'pressure_in': 30.3, 'precip_mm': 1.6, 'precip_in': 0.06, 'humidity': 99, 'cloud': 67, 'feelslike_c': 18.6, 'feelslike_f': 65.5, 'windchill_c': 18.6, 'windchill_f': 65.5, 'heatindex_c': 18.6, 'heatindex_f': 65.5, 'dewpoint_c': 18.4, 'dewpoint_f': 65.1, 'will_it_rain': 0, 'chance_of_rain': '41', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 6.7, 'vis_miles': 4.0, 'gust_mph': 10.1, 'gust_kph': 16.2, 'uv': 1.0}, {'time_epoch': 1624165200, 'time': '2021-06-20 01:00', 'temp_c': 18.2, 'temp_f': 64.8, 'is_day': 0, 'condition': {'text': 'Light rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png', 'code': 1240}, 'wind_mph': 4.9, 'wind_kph': 7.9, 'wind_degree': 225, 'wind_dir': 'SW', 'pressure_mb': 1009.0, 'pressure_in': 30.3, 'precip_mm': 0.8, 'precip_in': 0.03, 'humidity': 99, 'cloud': 84, 'feelslike_c': 18.2, 'feelslike_f': 64.8, 'windchill_c': 18.2, 'windchill_f': 64.8, 'heatindex_c': 18.2, 'heatindex_f': 64.8, 'dewpoint_c': 18.0, 'dewpoint_f': 64.4, 'will_it_rain': 0, 'chance_of_rain': '20', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 3.3, 'vis_miles': 2.0, 'gust_mph': 9.4, 'gust_kph': 15.1, 'uv': 1.0}, {'time_epoch': 1624168800, 'time': '2021-06-20 02:00', 'temp_c': 17.8, 'temp_f': 64.0, 'is_day': 0, 'condition': {'text': 'Fog', 'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png', 'code': 1135}, 'wind_mph': 4.5, 'wind_kph': 7.2, 'wind_degree': 220, 'wind_dir': 'SW', 'pressure_mb': 1009.0, 'pressure_in': 30.3, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 99, 'cloud': 100, 'feelslike_c': 17.8, 'feelslike_f': 64.0, 'windchill_c': 17.8, 'windchill_f': 64.0, 'heatindex_c': 17.8, 'heatindex_f': 64.0, 'dewpoint_c': 17.7, 'dewpoint_f': 63.9, 'will_it_rain': 0, 'chance_of_rain': '0', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 0.0, 'vis_miles': 0.0, 'gust_mph': 8.9, 'gust_kph': 14.4, 'uv': 1.0}, {'time_epoch': 1624172400, 'time': '2021-06-20 03:00', 'temp_c': 17.4, 'temp_f': 63.3, 'is_day': 0, 'condition': {'text': 'Light rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png', 'code': 1240}, 'wind_mph': 4.3, 'wind_kph': 6.8, 'wind_degree': 213, 'wind_dir': 'SSW', 'pressure_mb': 1009.0, 'pressure_in' ...

# %%
print(pittsburgh_daily.json()['forecast']['forecastday'])
# Out:
# [{'date': '2021-06-20', 'date_epoch': 1624147200, 'day': {'maxtemp_c': 30.0, 'maxtemp_f': 86.0, 'mintemp_c': 16.5, 'mintemp_f': 61.7, 'avgtemp_c': 23.2, 'avgtemp_f': 73.7, 'maxwind_mph': 9.6, 'maxwind_kph': 15.5, 'totalprecip_mm': 8.5, 'totalprecip_in': 0.33, 'avgvis_km': 8.3, 'avgvis_miles': 5.0, 'avghumidity': 85.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': '82', 'daily_will_it_snow': 0, 'daily_chance_of_snow': '0', 'condition': {'text': 'Moderate rain', 'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png', 'code': 1189}, 'uv': 9.0}, 'astro': {'sunrise': '05:50 AM', 'sunset': '08:54 PM', 'moonrise': '04:14 PM', 'moonset': '02:45 AM', 'moon_phase': 'Full Moon', 'moon_illumination': '76'}, 'hour': [{'time_epoch': 1624161600, 'time': '2021-06-20 00:00', 'temp_c': 18.6, 'temp_f': 65.5, 'is_day': 0, 'condition': {'text': 'Fog', 'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png', 'code': 1135}, 'wind_mph': 5.4, 'wind_kph': 8.6, 'wind_degree': 230, 'wind_dir': 'SW', 'pressure_mb': 1009.0, 'pressure_in': 30.3, 'precip_mm': 1.6, 'precip_in': 0.06, 'humidity': 99, 'cloud': 67, 'feelslike_c': 18.6, 'feelslike_f': 65.5, 'windchill_c': 18.6, 'windchill_f': 65.5, 'heatindex_c': 18.6, 'heatindex_f': 65.5, 'dewpoint_c': 18.4, 'dewpoint_f': 65.1, 'will_it_rain': 0, 'chance_of_rain': '41', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 6.7, 'vis_miles': 4.0, 'gust_mph': 10.1, 'gust_kph': 16.2, 'uv': 1.0}, {'time_epoch': 1624165200, 'time': '2021-06-20 01:00', 'temp_c': 18.2, 'temp_f': 64.8, 'is_day': 0, 'condition': {'text': 'Light rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png', 'code': 1240}, 'wind_mph': 4.9, 'wind_kph': 7.9, 'wind_degree': 225, 'wind_dir': 'SW', 'pressure_mb': 1009.0, 'pressure_in': 30.3, 'precip_mm': 0.8, 'precip_in': 0.03, 'humidity': 99, 'cloud': 84, 'feelslike_c': 18.2, 'feelslike_f': 64.8, 'windchill_c': 18.2, 'windchill_f': 64.8, 'heatindex_c': 18.2, 'heatindex_f': 64.8, 'dewpoint_c': 18.0, 'dewpoint_f': 64.4, 'will_it_rain': 0, 'chance_of_rain': '20', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 3.3, 'vis_miles': 2.0, 'gust_mph': 9.4, 'gust_kph': 15.1, 'uv': 1.0}, {'time_epoch': 1624168800, 'time': '2021-06-20 02:00', 'temp_c': 17.8, 'temp_f': 64.0, 'is_day': 0, 'condition': {'text': 'Fog', 'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png', 'code': 1135}, 'wind_mph': 4.5, 'wind_kph': 7.2, 'wind_degree': 220, 'wind_dir': 'SW', 'pressure_mb': 1009.0, 'pressure_in': 30.3, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 99, 'cloud': 100, 'feelslike_c': 17.8, 'feelslike_f': 64.0, 'windchill_c': 17.8, 'windchill_f': 64.0, 'heatindex_c': 17.8, 'heatindex_f': 64.0, 'dewpoint_c': 17.7, 'dewpoint_f': 63.9, 'will_it_rain': 0, 'chance_of_rain': '0', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 0.0, 'vis_miles': 0.0, 'gust_mph': 8.9, 'gust_kph': 14.4, 'uv': 1.0}, {'time_epoch': 1624172400, 'time': '2021-06-20 03:00', 'temp_c': 17.4, 'temp_f': 63.3, 'is_day': 0, 'condition': {'text': 'Light rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png', 'code': 1240}, 'wind_mph': 4.3, 'wind_kph': 6.8, 'wind_degree': 213, 'wind_dir': 'SSW', 'pressure_mb': 1009.0, 'pressure_in': 30.3, 'precip_mm': 0.6, 'precip_in': 0.02, 'humidity': 99, 'cloud': 86, 'feelslike_c': 17.4, 'feelslike_f': 63.3, 'windchill_c': 17.4, 'windchill_f': 63.3, 'heatindex_c': 17.4, 'heatindex_f': 63.3, 'dewpoint_c': 17.3, 'dewpoint_f': 63.1, 'will_it_rain': 0, 'chance_of_rain': '19', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 3.3, 'vis_miles': 2.0, 'gust_mph': 8.5, 'gust_kph': 13.7, 'uv': 1.0}, {'time_epoch': 1624176000, 'time': '2021-06-20 04:00', 'temp_c': 16.9, 'temp_f': 62.4, 'is_day': 0, 'condition': {'text': 'Fog', 'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png', 'code': 1135}, 'wind_mph': 3.8, 'wind_kph': 6.1, 'wind_degree': 207, 'wind_dir': 'SSW', 'pressure_mb': 1010.0, 'pressure_in': 30.3, 'precip_mm': 1.2, 'precip_in': 0.05, 'humidity': 99, 'cloud': 7 ...

# %%
next_seven_days = (pittsburgh_daily.json()['forecast']['forecastday'][0])
print(next_seven_days)
# Out:
# {'date': '2021-06-20', 'date_epoch': 1624147200, 'day': {'maxtemp_c': 30.0, 'maxtemp_f': 86.0, 'mintemp_c': 16.5, 'mintemp_f': 61.7, 'avgtemp_c': 23.2, 'avgtemp_f': 73.7, 'maxwind_mph': 9.6, 'maxwind_kph': 15.5, 'totalprecip_mm': 8.5, 'totalprecip_in': 0.33, 'avgvis_km': 8.3, 'avgvis_miles': 5.0, 'avghumidity': 85.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': '82', 'daily_will_it_snow': 0, 'daily_chance_of_snow': '0', 'condition': {'text': 'Moderate rain', 'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png', 'code': 1189}, 'uv': 9.0}, 'astro': {'sunrise': '05:50 AM', 'sunset': '08:54 PM', 'moonrise': '04:14 PM', 'moonset': '02:45 AM', 'moon_phase': 'Full Moon', 'moon_illumination': '76'}, 'hour': [{'time_epoch': 1624161600, 'time': '2021-06-20 00:00', 'temp_c': 18.6, 'temp_f': 65.5, 'is_day': 0, 'condition': {'text': 'Fog', 'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png', 'code': 1135}, 'wind_mph': 5.4, 'wind_kph': 8.6, 'wind_degree': 230, 'wind_dir': 'SW', 'pressure_mb': 1009.0, 'pressure_in': 30.3, 'precip_mm': 1.6, 'precip_in': 0.06, 'humidity': 99, 'cloud': 67, 'feelslike_c': 18.6, 'feelslike_f': 65.5, 'windchill_c': 18.6, 'windchill_f': 65.5, 'heatindex_c': 18.6, 'heatindex_f': 65.5, 'dewpoint_c': 18.4, 'dewpoint_f': 65.1, 'will_it_rain': 0, 'chance_of_rain': '41', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 6.7, 'vis_miles': 4.0, 'gust_mph': 10.1, 'gust_kph': 16.2, 'uv': 1.0}, {'time_epoch': 1624165200, 'time': '2021-06-20 01:00', 'temp_c': 18.2, 'temp_f': 64.8, 'is_day': 0, 'condition': {'text': 'Light rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png', 'code': 1240}, 'wind_mph': 4.9, 'wind_kph': 7.9, 'wind_degree': 225, 'wind_dir': 'SW', 'pressure_mb': 1009.0, 'pressure_in': 30.3, 'precip_mm': 0.8, 'precip_in': 0.03, 'humidity': 99, 'cloud': 84, 'feelslike_c': 18.2, 'feelslike_f': 64.8, 'windchill_c': 18.2, 'windchill_f': 64.8, 'heatindex_c': 18.2, 'heatindex_f': 64.8, 'dewpoint_c': 18.0, 'dewpoint_f': 64.4, 'will_it_rain': 0, 'chance_of_rain': '20', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 3.3, 'vis_miles': 2.0, 'gust_mph': 9.4, 'gust_kph': 15.1, 'uv': 1.0}, {'time_epoch': 1624168800, 'time': '2021-06-20 02:00', 'temp_c': 17.8, 'temp_f': 64.0, 'is_day': 0, 'condition': {'text': 'Fog', 'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png', 'code': 1135}, 'wind_mph': 4.5, 'wind_kph': 7.2, 'wind_degree': 220, 'wind_dir': 'SW', 'pressure_mb': 1009.0, 'pressure_in': 30.3, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 99, 'cloud': 100, 'feelslike_c': 17.8, 'feelslike_f': 64.0, 'windchill_c': 17.8, 'windchill_f': 64.0, 'heatindex_c': 17.8, 'heatindex_f': 64.0, 'dewpoint_c': 17.7, 'dewpoint_f': 63.9, 'will_it_rain': 0, 'chance_of_rain': '0', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 0.0, 'vis_miles': 0.0, 'gust_mph': 8.9, 'gust_kph': 14.4, 'uv': 1.0}, {'time_epoch': 1624172400, 'time': '2021-06-20 03:00', 'temp_c': 17.4, 'temp_f': 63.3, 'is_day': 0, 'condition': {'text': 'Light rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png', 'code': 1240}, 'wind_mph': 4.3, 'wind_kph': 6.8, 'wind_degree': 213, 'wind_dir': 'SSW', 'pressure_mb': 1009.0, 'pressure_in': 30.3, 'precip_mm': 0.6, 'precip_in': 0.02, 'humidity': 99, 'cloud': 86, 'feelslike_c': 17.4, 'feelslike_f': 63.3, 'windchill_c': 17.4, 'windchill_f': 63.3, 'heatindex_c': 17.4, 'heatindex_f': 63.3, 'dewpoint_c': 17.3, 'dewpoint_f': 63.1, 'will_it_rain': 0, 'chance_of_rain': '19', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 3.3, 'vis_miles': 2.0, 'gust_mph': 8.5, 'gust_kph': 13.7, 'uv': 1.0}, {'time_epoch': 1624176000, 'time': '2021-06-20 04:00', 'temp_c': 16.9, 'temp_f': 62.4, 'is_day': 0, 'condition': {'text': 'Fog', 'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png', 'code': 1135}, 'wind_mph': 3.8, 'wind_kph': 6.1, 'wind_degree': 207, 'wind_dir': 'SSW', 'pressure_mb': 1010.0, 'pressure_in': 30.3, 'precip_mm': 1.2, 'precip_in': 0.05, 'humidity': 99, 'cloud': 72 ...

# %%
print(next_seven_days['date_epoch'])
# Out:
# 1624147200

# %%
# I dont think this is the forecast for the next 7 days, just 1 day ... not sure how to forecast into the future

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?

# %%
# Same as above

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
# - *Tip: You'll only need one day of forecast*

# %%
miami = requests.get ("http://api.weatherapi.com/v1/forecast.json?key=a5a33e5547704451b06180649211906&q=miami&type=hour&start=current&end=24")
print(miami.json())
# Out:
# {'location': {'name': 'Miami', 'region': 'Florida', 'country': 'United States of America', 'lat': 25.77, 'lon': -80.19, 'tz_id': 'America/Kentucky/Monticello', 'localtime_epoch': 1624237546, 'localtime': '2021-06-20 21:05'}, 'current': {'last_updated_epoch': 1624233600, 'last_updated': '2021-06-20 20:00', 'temp_c': 26.7, 'temp_f': 80.1, 'is_day': 0, 'condition': {'text': 'Light rain', 'icon': '//cdn.weatherapi.com/weather/64x64/night/296.png', 'code': 1183}, 'wind_mph': 0.0, 'wind_kph': 0.0, 'wind_degree': 166, 'wind_dir': 'SSE', 'pressure_mb': 1018.0, 'pressure_in': 30.5, 'precip_mm': 0.6, 'precip_in': 0.02, 'humidity': 82, 'cloud': 75, 'feelslike_c': 29.3, 'feelslike_f': 84.7, 'vis_km': 16.0, 'vis_miles': 9.0, 'uv': 6.0, 'gust_mph': 16.1, 'gust_kph': 25.9}, 'forecast': {'forecastday': [{'date': '2021-06-20', 'date_epoch': 1624147200, 'day': {'maxtemp_c': 29.6, 'maxtemp_f': 85.3, 'mintemp_c': 27.9, 'mintemp_f': 82.2, 'avgtemp_c': 28.8, 'avgtemp_f': 83.8, 'maxwind_mph': 13.9, 'maxwind_kph': 22.3, 'totalprecip_mm': 9.5, 'totalprecip_in': 0.37, 'avgvis_km': 9.8, 'avgvis_miles': 6.0, 'avghumidity': 77.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': '88', 'daily_will_it_snow': 0, 'daily_chance_of_snow': '0', 'condition': {'text': 'Moderate rain', 'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png', 'code': 1189}, 'uv': 8.0}, 'astro': {'sunrise': '06:29 AM', 'sunset': '08:15 PM', 'moonrise': '03:59 PM', 'moonset': '02:57 AM', 'moon_phase': 'Full Moon', 'moon_illumination': '76'}, 'hour': [{'time_epoch': 1624161600, 'time': '2021-06-20 00:00', 'temp_c': 28.3, 'temp_f': 82.9, 'is_day': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png', 'code': 1063}, 'wind_mph': 12.3, 'wind_kph': 19.8, 'wind_degree': 109, 'wind_dir': 'ESE', 'pressure_mb': 1019.0, 'pressure_in': 30.6, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 80, 'cloud': 71, 'feelslike_c': 32.9, 'feelslike_f': 91.2, 'windchill_c': 28.3, 'windchill_f': 82.9, 'heatindex_c': 32.9, 'heatindex_f': 91.2, 'dewpoint_c': 24.4, 'dewpoint_f': 75.9, 'will_it_rain': 0, 'chance_of_rain': '29', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 16.6, 'gust_kph': 26.6, 'uv': 1.0}, {'time_epoch': 1624165200, 'time': '2021-06-20 01:00', 'temp_c': 28.3, 'temp_f': 82.9, 'is_day': 0, 'condition': {'text': 'Cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png', 'code': 1006}, 'wind_mph': 12.1, 'wind_kph': 19.4, 'wind_degree': 117, 'wind_dir': 'ESE', 'pressure_mb': 1018.0, 'pressure_in': 30.5, 'precip_mm': 0.1, 'precip_in': 0.0, 'humidity': 79, 'cloud': 77, 'feelslike_c': 32.9, 'feelslike_f': 91.2, 'windchill_c': 28.3, 'windchill_f': 82.9, 'heatindex_c': 32.9, 'heatindex_f': 91.2, 'dewpoint_c': 24.4, 'dewpoint_f': 75.9, 'will_it_rain': 0, 'chance_of_rain': '58', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 16.6, 'gust_kph': 26.6, 'uv': 1.0}, {'time_epoch': 1624168800, 'time': '2021-06-20 02:00', 'temp_c': 28.3, 'temp_f': 82.9, 'is_day': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png', 'code': 1063}, 'wind_mph': 11.9, 'wind_kph': 19.1, 'wind_degree': 126, 'wind_dir': 'SE', 'pressure_mb': 1018.0, 'pressure_in': 30.5, 'precip_mm': 0.1, 'precip_in': 0.0, 'humidity': 79, 'cloud': 84, 'feelslike_c': 32.8, 'feelslike_f': 91.0, 'windchill_c': 28.3, 'windchill_f': 82.9, 'heatindex_c': 32.8, 'heatindex_f': 91.0, 'dewpoint_c': 24.3, 'dewpoint_f': 75.7, 'will_it_rain': 1, 'chance_of_rain': '87', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 16.6, 'gust_kph': 26.6, 'uv': 1.0}, {'time_epoch': 1624172400, 'time': '2021-06-20 03:00', 'temp_c': 28.2, 'temp_f': 82.8, 'is_day': 0, 'condition': {'text': 'Light rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png', 'code': 1240}, 'wind_mph': 11.9, 'wind_kph': 19.1, 'wind_degree': 139, 'wind_dir ...

# %%
print(miami.json()['forecast']['forecastday'][0])
# Out:
# {'date': '2021-06-20', 'date_epoch': 1624147200, 'day': {'maxtemp_c': 29.6, 'maxtemp_f': 85.3, 'mintemp_c': 27.9, 'mintemp_f': 82.2, 'avgtemp_c': 28.8, 'avgtemp_f': 83.8, 'maxwind_mph': 13.9, 'maxwind_kph': 22.3, 'totalprecip_mm': 9.5, 'totalprecip_in': 0.37, 'avgvis_km': 9.8, 'avgvis_miles': 6.0, 'avghumidity': 77.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': '88', 'daily_will_it_snow': 0, 'daily_chance_of_snow': '0', 'condition': {'text': 'Moderate rain', 'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png', 'code': 1189}, 'uv': 8.0}, 'astro': {'sunrise': '06:29 AM', 'sunset': '08:15 PM', 'moonrise': '03:59 PM', 'moonset': '02:57 AM', 'moon_phase': 'Full Moon', 'moon_illumination': '76'}, 'hour': [{'time_epoch': 1624161600, 'time': '2021-06-20 00:00', 'temp_c': 28.3, 'temp_f': 82.9, 'is_day': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png', 'code': 1063}, 'wind_mph': 12.3, 'wind_kph': 19.8, 'wind_degree': 109, 'wind_dir': 'ESE', 'pressure_mb': 1019.0, 'pressure_in': 30.6, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 80, 'cloud': 71, 'feelslike_c': 32.9, 'feelslike_f': 91.2, 'windchill_c': 28.3, 'windchill_f': 82.9, 'heatindex_c': 32.9, 'heatindex_f': 91.2, 'dewpoint_c': 24.4, 'dewpoint_f': 75.9, 'will_it_rain': 0, 'chance_of_rain': '29', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 16.6, 'gust_kph': 26.6, 'uv': 1.0}, {'time_epoch': 1624165200, 'time': '2021-06-20 01:00', 'temp_c': 28.3, 'temp_f': 82.9, 'is_day': 0, 'condition': {'text': 'Cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png', 'code': 1006}, 'wind_mph': 12.1, 'wind_kph': 19.4, 'wind_degree': 117, 'wind_dir': 'ESE', 'pressure_mb': 1018.0, 'pressure_in': 30.5, 'precip_mm': 0.1, 'precip_in': 0.0, 'humidity': 79, 'cloud': 77, 'feelslike_c': 32.9, 'feelslike_f': 91.2, 'windchill_c': 28.3, 'windchill_f': 82.9, 'heatindex_c': 32.9, 'heatindex_f': 91.2, 'dewpoint_c': 24.4, 'dewpoint_f': 75.9, 'will_it_rain': 0, 'chance_of_rain': '58', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 16.6, 'gust_kph': 26.6, 'uv': 1.0}, {'time_epoch': 1624168800, 'time': '2021-06-20 02:00', 'temp_c': 28.3, 'temp_f': 82.9, 'is_day': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png', 'code': 1063}, 'wind_mph': 11.9, 'wind_kph': 19.1, 'wind_degree': 126, 'wind_dir': 'SE', 'pressure_mb': 1018.0, 'pressure_in': 30.5, 'precip_mm': 0.1, 'precip_in': 0.0, 'humidity': 79, 'cloud': 84, 'feelslike_c': 32.8, 'feelslike_f': 91.0, 'windchill_c': 28.3, 'windchill_f': 82.9, 'heatindex_c': 32.8, 'heatindex_f': 91.0, 'dewpoint_c': 24.3, 'dewpoint_f': 75.7, 'will_it_rain': 1, 'chance_of_rain': '87', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 16.6, 'gust_kph': 26.6, 'uv': 1.0}, {'time_epoch': 1624172400, 'time': '2021-06-20 03:00', 'temp_c': 28.2, 'temp_f': 82.8, 'is_day': 0, 'condition': {'text': 'Light rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png', 'code': 1240}, 'wind_mph': 11.9, 'wind_kph': 19.1, 'wind_degree': 139, 'wind_dir': 'SE', 'pressure_mb': 1018.0, 'pressure_in': 30.5, 'precip_mm': 0.6, 'precip_in': 0.02, 'humidity': 80, 'cloud': 73, 'feelslike_c': 32.7, 'feelslike_f': 90.9, 'windchill_c': 28.2, 'windchill_f': 82.8, 'heatindex_c': 32.7, 'heatindex_f': 90.9, 'dewpoint_c': 24.4, 'dewpoint_f': 75.9, 'will_it_rain': 1, 'chance_of_rain': '82', 'will_it_snow': 0, 'chance_of_snow': '0', 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 16.8, 'gust_kph': 27.0, 'uv': 1.0}, {'time_epoch': 1624176000, 'time': '2021-06-20 04:00', 'temp_c': 28.0, 'temp_f': 82.4, 'is_day': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png', 'code': 1063}, 'wind_mph': 12.1, 'wind_kph': 19.4, 'wind_degree': 151, 'wind_dir': 'SSE', 'pressure_mb': 1017.0, 'pressure_in': 30.5, 'precip ...

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %%
miami.json()['forecast']['forecastday'][0]
# Out:
# {'date': '2021-06-20',
#  'date_epoch': 1624147200,
#  'day': {'maxtemp_c': 29.6,
#   'maxtemp_f': 85.3,
#   'mintemp_c': 27.9,
#   'mintemp_f': 82.2,
#   'avgtemp_c': 28.8,
#   'avgtemp_f': 83.8,
#   'maxwind_mph': 13.9,
#   'maxwind_kph': 22.3,
#   'totalprecip_mm': 9.5,
#   'totalprecip_in': 0.37,
#   'avgvis_km': 9.8,
#   'avgvis_miles': 6.0,
#   'avghumidity': 77.0,
#   'daily_will_it_rain': 1,
#   'daily_chance_of_rain': '88',
#   'daily_will_it_snow': 0,
#   'daily_chance_of_snow': '0',
#   'condition': {'text': 'Moderate rain',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png',
#    'code': 1189},
#   'uv': 8.0},
#  'astro': {'sunrise': '06:29 AM',
#   'sunset': '08:15 PM',
#   'moonrise': '03:59 PM',
#   'moonset': '02:57 AM',
#   'moon_phase': 'Full Moon',
#   'moon_illumination': '76'},
#  'hour': [{'time_epoch': 1624161600,
#    'time': '2021-06-20 00:00',
#    'temp_c': 28.3,
#    'temp_f': 82.9,
#    'is_day': 0,
#    'condition': {'text': 'Patchy rain possible',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#     'code': 1063},
#    'wind_mph': 12.3,
#    'wind_kph': 19.8,
#    'wind_degree': 109,
#    'wind_dir': 'ESE',
#    'pressure_mb': 1019.0,
#    'pressure_in': 30.6,
#    'precip_mm': 0.0,
#    'precip_in': 0.0,
#    'humidity': 80,
#    'cloud': 71,
#    'feelslike_c': 32.9,
#    'feelslike_f': 91.2,
#    'windchill_c': 28.3,
#    'windchill_f': 82.9,
#    'heatindex_c': 32.9,
#    'heatindex_f': 91.2,
#    'dewpoint_c': 24.4,
#    'dewpoint_f': 75.9,
#    'will_it_rain': 0,
#    'chance_of_rain': '29',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 16.6,
#    'gust_kph': 26.6,
#    'uv': 1.0},
#   {'time_epoch': 1624165200,
#    'time': '2021-06-20 01:00',
#    'temp_c': 28.3,
#    'temp_f': 82.9,
#    'is_day': 0,
#    'condition': {'text': 'Cloudy',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#     'code': 1006},
#    'wind_mph': 12.1,
#    'wind_kph': 19.4,
#    'wind_degree': 117,
#    'wind_dir': 'ESE',
#    'pressure_mb': 1018.0,
#    'pressure_in': 30.5,
#    'precip_mm': 0.1,
#    'precip_in': 0.0,
#    'humidity': 79,
#    'cloud': 77,
#    'feelslike_c': 32.9,
#    'feelslike_f': 91.2,
#    'windchill_c': 28.3,
#    'windchill_f': 82.9,
#    'heatindex_c': 32.9,
#    'heatindex_f': 91.2,
#    'dewpoint_c': 24.4,
#    'dewpoint_f': 75.9,
#    'will_it_rain': 0,
#    'chance_of_rain': '58',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 16.6,
#    'gust_kph': 26.6,
#    'uv': 1.0},
#   {'time_epoch': 1624168800,
#    'time': '2021-06-20 02:00',
#    'temp_c': 28.3,
#    'temp_f': 82.9,
#    'is_day': 0,
#    'condition': {'text': 'Patchy rain possible',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#     'code': 1063},
#    'wind_mph': 11.9,
#    'wind_kph': 19.1,
#    'wind_degree': 126,
#    'wind_dir': 'SE',
#    'pressure_mb': 1018.0,
#    'pressure_in': 30.5,
#    'precip_mm': 0.1,
#    'precip_in': 0.0,
#    'humidity': 79,
#    'cloud': 84,
#    'feelslike_c': 32.8,
#    'feelslike_f': 91.0,
#    'windchill_c': 28.3,
#    'windchill_f': 82.9,
#    'heatindex_c': 32.8,
#    'heatindex_f': 91.0,
#    'dewpoint_c': 24.3,
#    'dewpoint_f': 75.7,
#    'will_it_rain': 1,
#    'chance_of_rain': '87',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 16.6,
#    'gust_kph': 26.6,
#    'uv': 1.0},
#   {'time_epoch': 1624172400,
#    'time': '2021-06-20 03:00',
#    'temp_c': 28.2,
#    'temp_f': 82.8,
#    'is_day': 0,
#    'condition': {'text': 'Light rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#     'code': 1240},
#    'wind_mph': 11.9,
#    'wind_kph': 19.1,
#    'wind_degree': 139,
#    'wind_dir': 'SE',
#    'pressure_mb': 1018.0,
#    'pressure_in': 30.5,
#    'precip_mm': 0.6,
#    'precip_in': 0.02,
#    'humidity': 80,
#    'cloud': 73,
#    'feelslike_c': 32.7,
#    'feelslike_f': 90.9,
#    'windchill_c': 28.2,
#    'windchill_f': 82.8,
#    'heatindex_c': 32.7,
#    'heatindex_f': 90.9,
#    'dewpoint_c': 24.4,
#    'dewpoint_f': 75.9,
#    'will_it_rain': 1,
#    'chance_of_rain': '82',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 16.8,
#    'gust_kph': 27.0,
#    'uv': 1.0},
#   {'time_epoch': 1624176000,
#    'time': '2021-06-20 04:00',
#    'temp_c': 28.0,
#    'temp_f': 82.4,
#    'is_day': 0,
#    'condition': {'text': 'Patchy rain possible',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#     'code': 1063},
#    'wind_mph': 12.1,
#    'wind_kph': 19.4,
#    'wind_degree': 151,
#    'wind_dir': 'SSE',
#    'pressure_mb': 1017.0,
#    'pressure_in': 30.5,
#    'precip_mm': 1.0,
#    'precip_in': 0.04,
#    'humidity': 81,
#    'cloud': 63,
#    'feelslike_c': 32.6,
#    'feelslike_f': 90.7,
#    'windchill_c': 28.0,
#    'windchill_f': 82.4,
#    'heatindex_c': 32.6,
#    'heatindex_f': 90.7,
#    'dewpoint_c': 24.5,
#    'dewpoint_f': 76.1,
#    'will_it_rain': 1,
#    'chance_of_rain': '76',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 16.8,
#    'gust_kph': 27.0,
#    'uv': 1.0},
#   {'time_epoch': 1624179600,
#    'time': '2021-06-20 05:00',
#    'temp_c': 27.9,
#    'temp_f': 82.2,
#    'is_day': 0,
#    'condition': {'text': 'Light rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#     'code': 1240},
#    'wind_mph': 12.1,
#    'wind_kph': 19.4,
#    'wind_degree': 164,
#    'wind_dir': 'SSE',
#    'pressure_mb': 1017.0,
#    'pressure_in': 30.5,
#    'precip_mm': 1.5,
#    'precip_in': 0.06,
#    'humidity': 82,
#    'cloud': 52,
#    'feelslike_c': 32.5,
#    'feelslike_f': 90.5,
#    'windchill_c': 27.9,
#    'windchill_f': 82.2,
#    'heatindex_c': 32.5,
#    'heatindex_f': 90.5,
#    'dewpoint_c': 24.6,
#    'dewpoint_f': 76.3,
#    'will_it_rain': 1,
#    'chance_of_rain': '71',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 17.0,
#    'gust_kph': 27.4,
#    'uv': 1.0},
#   {'time_epoch': 1624183200,
#    'time': '2021-06-20 06:00',
#    'temp_c': 28.0,
#    'temp_f': 82.4,
#    'is_day': 0,
#    'condition': {'text': 'Light rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#     'code': 1240},
#    'wind_mph': 11.9,
#    'wind_kph': 19.1,
#    'wind_degree': 166,
#    'wind_dir': 'SSE',
#    'pressure_mb': 1018.0,
#    'pressure_in': 30.5,
#    'precip_mm': 1.2,
#    'precip_in': 0.05,
#    'humidity': 82,
#    'cloud': 57,
#    'feelslike_c': 32.6,
#    'feelslike_f': 90.7,
#    'windchill_c': 28.0,
#    'windchill_f': 82.4,
#    'heatindex_c': 32.6,
#    'heatindex_f': 90.7,
#    'dewpoint_c': 24.6,
#    'dewpoint_f': 76.3,
#    'will_it_rain': 1,
#    'chance_of_rain': '72',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 16.6,
#    'gust_kph': 26.6,
#    'uv': 1.0},
#   {'time_epoch': 1624186800,
#    'time': '2021-06-20 07:00',
#    'temp_c': 28.2,
#    'temp_f': 82.8,
#    'is_day': 1,
#    'condition': {'text': 'Light rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#     'code': 1240},
#    'wind_mph': 11.6,
#    'wind_kph': 18.7,
#    'wind_degree': 169,
#    'wind_dir': 'S',
#    'pressure_mb': 1018.0,
#    'pressure_in': 30.5,
#    'precip_mm': 0.8,
#    'precip_in': 0.03,
#    'humidity': 81,
#    'cloud': 61,
#    'feelslike_c': 32.8,
#    'feelslike_f': 91.0,
#    'windchill_c': 28.2,
#    'windchill_f': 82.8,
#    'heatindex_c': 32.8,
#    'heatindex_f': 91.0,
#    'dewpoint_c': 24.5,
#    'dewpoint_f': 76.1,
#    'will_it_rain': 1,
#    'chance_of_rain': '73',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 15.9,
#    'gust_kph': 25.6,
#    'uv': 6.0},
#   {'time_epoch': 1624190400,
#    'time': '2021-06-20 08:00',
#    'temp_c': 28.3,
#    'temp_f': 82.9,
#    'is_day': 1,
#    'condition': {'text': 'Light rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#     'code': 1240},
#    'wind_mph': 11.4,
#    'wind_kph': 18.4,
#    'wind_degree': 172,
#    'wind_dir': 'S',
#    'pressure_mb': 1019.0,
#    'pressure_in': 30.6,
#    'precip_mm': 0.5,
#    'precip_in': 0.02,
#    'humidity': 80,
#    'cloud': 66,
#    'feelslike_c': 32.9,
#    'feelslike_f': 91.2,
#    'windchill_c': 28.3,
#    'windchill_f': 82.9,
#    'heatindex_c': 32.9,
#    'heatindex_f': 91.2,
#    'dewpoint_c': 24.5,
#    'dewpoint_f': 76.1,
#    'will_it_rain': 1,
#    'chance_of_rain': '74',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 15.4,
#    'gust_kph': 24.8,
#    'uv': 6.0},
#   {'time_epoch': 1624194000,
#    'time': '2021-06-20 09:00',
#    'temp_c': 28.6,
#    'temp_f': 83.5,
#    'is_day': 1,
#    'condition': {'text': 'Patchy rain possible',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#     'code': 1063},
#    'wind_mph': 11.2,
#    'wind_kph': 18.0,
#    'wind_degree': 171,
#    'wind_dir': 'S',
#    'pressure_mb': 1019.0,
#    'pressure_in': 30.6,
#    'precip_mm': 1.2,
#    'precip_in': 0.05,
#    'humidity': 78,
#    'cloud': 72,
#    'feelslike_c': 33.3,
#    'feelslike_f': 91.9,
#    'windchill_c': 28.6,
#    'windchill_f': 83.5,
#    'heatindex_c': 33.3,
#    'heatindex_f': 91.9,
#    'dewpoint_c': 24.4,
#    'dewpoint_f': 75.9,
#    'will_it_rain': 1,
#    'chance_of_rain': '77',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 9.7,
#    'vis_miles': 6.0,
#    'gust_mph': 15.7,
#    'gust_kph': 25.2,
#    'uv': 6.0},
#   {'time_epoch': 1624197600,
#    'time': '2021-06-20 10:00',
#    'temp_c': 29.0,
#    'temp_f': 84.2,
#    'is_day': 1,
#    'condition': {'text': 'Light rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#     'code': 1240},
#    'wind_mph': 10.7,
#    'wind_kph': 17.3,
#    'wind_degree': 170,
#    'wind_dir': 'S',
#    'pressure_mb': 1019.0,
#    'pressure_in': 30.6,
#    'precip_mm': 1.8,
#    'precip_in': 0.07,
#    'humidity': 76,
#    'cloud': 77,
#    'feelslike_c': 33.8,
#    'feelslike_f': 92.8,
#    'windchill_c': 29.0,
#    'windchill_f': 84.2,
#    'heatindex_c': 33.8,
#    'heatindex_f': 92.8,
#    'dewpoint_c': 24.2,
#    'dewpoint_f': 75.6,
#    'will_it_rain': 1,
#    'chance_of_rain': '81',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 9.3,
#    'vis_miles': 5.0,
#    'gust_mph': 16.1,
#    'gust_kph': 25.9,
#    'uv': 6.0},
#   {'time_epoch': 1624201200,
#    'time': '2021-06-20 11:00',
#    'temp_c': 29.3,
#    'temp_f': 84.7,
#    'is_day': 1,
#    'condition': {'text': 'Patchy rain possible',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#     'code': 1063},
#    'wind_mph': 10.5,
#    'wind_kph': 16.9,
#    'wind_degree': 170,
#    'wind_dir': 'S',
#    'pressure_mb': 1020.0,
#    'pressure_in': 30.6,
#    'precip_mm': 2.5,
#    'precip_in': 0.1,
#    'humidity': 74,
#    'cloud': 83,
#    'feelslike_c': 34.2,
#    'feelslike_f': 93.6,
#    'windchill_c': 29.3,
#    'windchill_f': 84.7,
#    'heatindex_c': 34.2,
#    'heatindex_f': 93.6,
#    'dewpoint_c': 24.1,
#    'dewpoint_f': 75.4,
#    'will_it_rain': 1,
#    'chance_of_rain': '84',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 16.3,
#    'gust_kph': 26.3,
#    'uv': 6.0},
#   {'time_epoch': 1624204800,
#    'time': '2021-06-20 12:00',
#    'temp_c': 29.4,
#    'temp_f': 84.9,
#    'is_day': 1,
#    'condition': {'text': 'Patchy light rain with thunder',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#     'code': 1273},
#    'wind_mph': 11.6,
#    'wind_kph': 18.7,
#    'wind_degree': 167,
#    'wind_dir': 'SSE',
#    'pressure_mb': 1019.0,
#    'pressure_in': 30.6,
#    'precip_mm': 2.2,
#    'precip_in': 0.09,
#    'humidity': 74,
#    'cloud': 82,
#    'feelslike_c': 34.4,
#    'feelslike_f': 93.9,
#    'windchill_c': 29.4,
#    'windchill_f': 84.9,
#    'heatindex_c': 34.4,
#    'heatindex_f': 93.9,
#    'dewpoint_c': 24.2,
#    'dewpoint_f': 75.6,
#    'will_it_rain': 1,
#    'chance_of_rain': '73',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 9.3,
#    'vis_miles': 5.0,
#    'gust_mph': 17.4,
#    'gust_kph': 28.1,
#    'uv': 6.0},
#   {'time_epoch': 1624208400,
#    'time': '2021-06-20 13:00',
#    'temp_c': 29.5,
#    'temp_f': 85.1,
#    'is_day': 1,
#    'condition': {'text': 'Patchy rain possible',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#     'code': 1063},
#    'wind_mph': 12.8,
#    'wind_kph': 20.5,
#    'wind_degree': 164,
#    'wind_dir': 'SSE',
#    'pressure_mb': 1018.0,
#    'pressure_in': 30.6,
#    'precip_mm': 1.8,
#    'precip_in': 0.07,
#    'humidity': 74,
#    'cloud': 80,
#    'feelslike_c': 34.6,
#    'feelslike_f': 94.3,
#    'windchill_c': 29.5,
#    'windchill_f': 85.1,
#    'heatindex_c': 34.6,
#    'heatindex_f': 94.3,
#    'dewpoint_c': 24.3,
#    'dewpoint_f': 75.7,
#    'will_it_rain': 0,
#    'chance_of_rain': '61',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 9.7,
#    'vis_miles': 6.0,
#    'gust_mph': 18.3,
#    'gust_kph': 29.5,
#    'uv': 6.0},
#   {'time_epoch': 1624212000,
#    'time': '2021-06-20 14:00',
#    'temp_c': 29.6,
#    'temp_f': 85.3,
#    'is_day': 1,
#    'condition': {'text': 'Patchy light rain with thunder',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#     'code': 1273},
#    'wind_mph': 13.9,
#    'wind_kph': 22.3,
#    'wind_degree': 160,
#    'wind_dir': 'SSE',
#    'pressure_mb': 1018.0,
#    'pressure_in': 30.5,
#    'precip_mm': 1.5,
#    'precip_in': 0.06,
#    'humidity': 74,
#    'cloud': 79,
#    'feelslike_c': 34.8,
#    'feelslike_f': 94.6,
#    'windchill_c': 29.6,
#    'windchill_f': 85.3,
#    'heatindex_c': 34.8,
#    'heatindex_f': 94.6,
#    'dewpoint_c': 24.4,
#    'dewpoint_f': 75.9,
#    'will_it_rain': 0,
#    'chance_of_rain': '50',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 19.5,
#    'gust_kph': 31.3,
#    'uv': 6.0},
#   {'time_epoch': 1624215600,
#    'time': '2021-06-20 15:00',
#    'temp_c': 29.6,
#    'temp_f': 85.3,
#    'is_day': 1,
#    'condition': {'text': 'Patchy light rain with thunder',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#     'code': 1273},
#    'wind_mph': 13.4,
#    'wind_kph': 21.6,
#    'wind_degree': 162,
#    'wind_dir': 'SSE',
#    'pressure_mb': 1018.0,
#    'pressure_in': 30.5,
#    'precip_mm': 1.3,
#    'precip_in': 0.05,
#    'humidity': 74,
#    'cloud': 81,
#    'feelslike_c': 34.9,
#    'feelslike_f': 94.8,
#    'windchill_c': 29.6,
#    'windchill_f': 85.3,
#    'heatindex_c': 34.9,
#    'heatindex_f': 94.8,
#    'dewpoint_c': 24.5,
#    'dewpoint_f': 76.1,
#    'will_it_rain': 0,
#    'chance_of_rain': '62',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 18.3,
#    'gust_kph': 29.5,
#    'uv': 6.0},
#   {'time_epoch': 1624219200,
#    'time': '2021-06-20 16:00',
#    'temp_c': 29.6,
#    'temp_f': 85.3,
#    'is_day': 1,
#    'condition': {'text': 'Patchy light rain with thunder',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#     'code': 1273},
#    'wind_mph': 12.8,
#    'wind_kph': 20.5,
#    'wind_degree': 164,
#    'wind_dir': 'SSE',
#    'pressure_mb': 1017.0,
#    'pressure_in': 30.5,
#    'precip_mm': 1.0,
#    'precip_in': 0.04,
#    'humidity': 74,
#    'cloud': 82,
#    'feelslike_c': 34.9,
#    'feelslike_f': 94.8,
#    'windchill_c': 29.6,
#    'windchill_f': 85.3,
#    'heatindex_c': 34.9,
#    'heatindex_f': 94.8,
#    'dewpoint_c': 24.5,
#    'dewpoint_f': 76.1,
#    'will_it_rain': 1,
#    'chance_of_rain': '74',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 17.0,
#    'gust_kph': 27.4,
#    'uv': 6.0},
#   {'time_epoch': 1624222800,
#    'time': '2021-06-20 17:00',
#    'temp_c': 29.6,
#    'temp_f': 85.3,
#    'is_day': 1,
#    'condition': {'text': 'Patchy light rain with thunder',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#     'code': 1273},
#    'wind_mph': 12.3,
#    'wind_kph': 19.8,
#    'wind_degree': 165,
#    'wind_dir': 'SSE',
#    'pressure_mb': 1017.0,
#    'pressure_in': 30.5,
#    'precip_mm': 0.8,
#    'precip_in': 0.03,
#    'humidity': 74,
#    'cloud': 84,
#    'feelslike_c': 35.0,
#    'feelslike_f': 95.0,
#    'windchill_c': 29.6,
#    'windchill_f': 85.3,
#    'heatindex_c': 35.0,
#    'heatindex_f': 95.0,
#    'dewpoint_c': 24.6,
#    'dewpoint_f': 76.3,
#    'will_it_rain': 1,
#    'chance_of_rain': '86',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 15.9,
#    'gust_kph': 25.6,
#    'uv': 6.0},
#   {'time_epoch': 1624226400,
#    'time': '2021-06-20 18:00',
#    'temp_c': 29.4,
#    'temp_f': 84.9,
#    'is_day': 1,
#    'condition': {'text': 'Patchy rain possible',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#     'code': 1063},
#    'wind_mph': 12.3,
#    'wind_kph': 19.8,
#    'wind_degree': 166,
#    'wind_dir': 'SSE',
#    'pressure_mb': 1017.0,
#    'pressure_in': 30.5,
#    'precip_mm': 0.6,
#    'precip_in': 0.02,
#    'humidity': 76,
#    'cloud': 81,
#    'feelslike_c': 34.7,
#    'feelslike_f': 94.5,
#    'windchill_c': 29.4,
#    'windchill_f': 84.9,
#    'heatindex_c': 34.7,
#    'heatindex_f': 94.5,
#    'dewpoint_c': 24.6,
#    'dewpoint_f': 76.3,
#    'will_it_rain': 1,
#    'chance_of_rain': '87',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 9.7,
#    'vis_miles': 6.0,
#    'gust_mph': 16.1,
#    'gust_kph': 25.9,
#    'uv': 6.0},
#   {'time_epoch': 1624230000,
#    'time': '2021-06-20 19:00',
#    'temp_c': 29.2,
#    'temp_f': 84.6,
#    'is_day': 1,
#    'condition': {'text': 'Patchy light rain with thunder',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/386.png',
#     'code': 1273},
#    'wind_mph': 12.3,
#    'wind_kph': 19.8,
#    'wind_degree': 166,
#    'wind_dir': 'SSE',
#    'pressure_mb': 1017.0,
#    'pressure_in': 30.5,
#    'precip_mm': 0.4,
#    'precip_in': 0.02,
#    'humidity': 77,
#    'cloud': 77,
#    'feelslike_c': 34.5,
#    'feelslike_f': 94.1,
#    'windchill_c': 29.2,
#    'windchill_f': 84.6,
#    'heatindex_c': 34.5,
#    'heatindex_f': 94.1,
#    'dewpoint_c': 24.7,
#    'dewpoint_f': 76.5,
#    'will_it_rain': 1,
#    'chance_of_rain': '87',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 9.3,
#    'vis_miles': 5.0,
#    'gust_mph': 16.6,
#    'gust_kph': 26.6,
#    'uv': 6.0},
#   {'time_epoch': 1624233600,
#    'time': '2021-06-20 20:00',
#    'temp_c': 29.0,
#    'temp_f': 84.2,
#    'is_day': 1,
#    'condition': {'text': 'Patchy rain possible',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#     'code': 1063},
#    'wind_mph': 12.3,
#    'wind_kph': 19.8,
#    'wind_degree': 167,
#    'wind_dir': 'SSE',
#    'pressure_mb': 1018.0,
#    'pressure_in': 30.5,
#    'precip_mm': 0.2,
#    'precip_in': 0.01,
#    'humidity': 78,
#    'cloud': 74,
#    'feelslike_c': 34.2,
#    'feelslike_f': 93.6,
#    'windchill_c': 29.0,
#    'windchill_f': 84.2,
#    'heatindex_c': 34.2,
#    'heatindex_f': 93.6,
#    'dewpoint_c': 24.7,
#    'dewpoint_f': 76.5,
#    'will_it_rain': 1,
#    'chance_of_rain': '88',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 9.0,
#    'vis_miles': 5.0,
#    'gust_mph': 16.8,
#    'gust_kph': 27.0,
#    'uv': 6.0},
#   {'time_epoch': 1624237200,
#    'time': '2021-06-20 21:00',
#    'temp_c': 28.8,
#    'temp_f': 83.8,
#    'is_day': 0,
#    'condition': {'text': 'Light rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#     'code': 1240},
#    'wind_mph': 11.2,
#    'wind_kph': 18.0,
#    'wind_degree': 171,
#    'wind_dir': 'S',
#    'pressure_mb': 1018.0,
#    'pressure_in': 30.5,
#    'precip_mm': 0.9,
#    'precip_in': 0.04,
#    'humidity': 78,
#    'cloud': 79,
#    'feelslike_c': 33.8,
#    'feelslike_f': 92.8,
#    'windchill_c': 28.8,
#    'windchill_f': 83.8,
#    'heatindex_c': 33.8,
#    'heatindex_f': 92.8,
#    'dewpoint_c': 24.5,
#    'dewpoint_f': 76.1,
#    'will_it_rain': 1,
#    'chance_of_rain': '81',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 9.3,
#    'vis_miles': 5.0,
#    'gust_mph': 15.9,
#    'gust_kph': 25.6,
#    'uv': 1.0},
#   {'time_epoch': 1624240800,
#    'time': '2021-06-20 22:00',
#    'temp_c': 28.6,
#    'temp_f': 83.5,
#    'is_day': 0,
#    'condition': {'text': 'Patchy rain possible',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#     'code': 1063},
#    'wind_mph': 10.3,
#    'wind_kph': 16.6,
#    'wind_degree': 175,
#    'wind_dir': 'S',
#    'pressure_mb': 1018.0,
#    'pressure_in': 30.6,
#    'precip_mm': 1.7,
#    'precip_in': 0.07,
#    'humidity': 78,
#    'cloud': 84,
#    'feelslike_c': 33.3,
#    'feelslike_f': 91.9,
#    'windchill_c': 28.6,
#    'windchill_f': 83.5,
#    'heatindex_c': 33.3,
#    'heatindex_f': 91.9,
#    'dewpoint_c': 24.4,
#    'dewpoint_f': 75.9,
#    'will_it_rain': 1,
#    'chance_of_rain': '74',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 9.7,
#    'vis_miles': 6.0,
#    'gust_mph': 15.0,
#    'gust_kph': 24.1,
#    'uv': 1.0},
#   {'time_epoch': 1624244400,
#    'time': '2021-06-20 23:00',
#    'temp_c': 28.4,
#    'temp_f': 83.1,
#    'is_day': 0,
#    'condition': {'text': 'Light rain shower',
#     'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#     'code': 1240},
#    'wind_mph': 9.2,
#    'wind_kph': 14.8,
#    'wind_degree': 179,
#    'wind_dir': 'S',
#    'pressure_mb': 1019.0,
#    'pressure_in': 30.6,
#    'precip_mm': 2.4,
#    'precip_in': 0.09,
#    'humidity': 78,
#    'cloud': 89,
#    'feelslike_c': 32.9,
#    'feelslike_f': 91.2,
#    'windchill_c': 28.4,
#    'windchill_f': 83.1,
#    'heatindex_c': 32.9,
#    'heatindex_f': 91.2,
#    'dewpoint_c': 24.2,
#    'dewpoint_f': 75.6,
#    'will_it_rain': 0,
#    'chance_of_rain': '67',
#    'will_it_snow': 0,
#    'chance_of_snow': '0',
#    'vis_km': 10.0,
#    'vis_miles': 6.0,
#    'gust_mph': 14.1,
#    'gust_kph': 22.7,
#    'uv': 1.0}]}

# %%
daily_temperature = miami.json()['forecast']['forecastday'][0]
for hour in daily_temperature:
    if daily_temperature['day']['avgtemp_f'] > 85:
        print(daily_temperature['day']['avgtemp_f'])

# %%
print("The average daily temperature will not exceed 85 degrees.")
# Out:
# The average daily temperature will not exceed 85 degrees.

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2020? How about 2012? 2007? How far back does the API allow you to go?
#
# - *Tip: You'll need to use latitude/longitude. You can ask Google where Central Park is, it knows*
# - *Tip: Remember when latitude/longitude might use negative numbers*

# %%
christmas_day = requests.get ("http://api.weatherapi.com/v1/history.json?key=a5a33e5547704451b06180649211906&q=10019&dt=2020-12-25")
print(christmas_day.json())
# Out:
# {'error': {'code': 1008, 'message': 'API key is limited to get history data. Please check our pricing page and upgrade to higher plan.'}}

# %% [markdown]
# The API will only let you go back to January 1, 2010. Not sure what the above means ... do you need to pay to access historical data?
